# %%
import sys
sys.executable
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit
from collections import defaultdict
import matplotlib.ticker as ticker
import glob
import os
import pickle
import sys
import re
import ast
sys.path.append("/scratch/halmazan//WCTE/WCTECoincidence_Analysis/Complete_analysis")

from matplotlib import rcParams
rcParams['mathtext.fontset'] = 'stix'
rcParams['font.family'] = 'STIXGeneral'
rcParams['figure.figsize'] = [10, 8]
rcParams['font.size'] = 22

# %%
def deltaR(df, pos):
    """
    df: DataFrame with delayed_x/y/z (and optionally prompt_x/y/z if you still want them)
    pos: iterable of length 3 -> (prompt_x, prompt_y, prompt_z) to use for all rows
    """
    # Ensure numeric delayed columns
    dcols = ["delayed_x", "delayed_y", "delayed_z"]
    for c in dcols:
        df[c] = pd.to_numeric(df[c], errors="coerce")

    # Fixed prompt position (broadcast to all rows)
    pos = np.asarray(pos, dtype=float).reshape(3,)
    prompt_r = np.linalg.norm(pos)

    # Row-wise delayed radius
    d = df[dcols].to_numpy(dtype=float)
    df["delayed_r"] = np.linalg.norm(d, axis=1)

    # Store prompt_r as a constant column (optional)
    df["prompt_r"] = prompt_r

    # DeltaR: |r_delayed - r_prompt|
    df["DeltaR"] = np.abs(df["delayed_r"] - prompt_r)

def deltaT(df):
    # DeltaT: Time difference between prompt and delayed vertices
    df["DeltaT"] = np.abs(df["delayed_time_tof"]/1000 - df["prompt_time"]/1000)

def exp_func(x, A, tau):
    return A * np.exp(-x / tau)

# %%
#Runs to compare 
sig_run = '2389'
pos = []
bkg_run = '2384'


pos = []
sources_pos = {
    '2386': [0.0, 729.725, 0.0],
    '2387': [0.0, 119.725, 0.0],
    '2388': [0.0, -160.275, 0.0],
    '2389': [-476.4, 729.725, 291.7],
    '2390': [-476.4, 119.725, 291.7],

    #'2386': [0.0, +30.5, 0.0],
    #'2387': [0.0, -30.5, 0.0],
    #'2388': [0.0, -58.5, 0.0],
    #'2389': [-47.64, +30.5, 29.17],
    #'2390': [-47.64, -30.5, 29.17], 
}
if sig_run in sources_pos.keys():
    pos = sources_pos[sig_run]
else:
    print('Run not on list')


prompt_window = 1000  # Window for prompt candidates
prompt_dead_time = 200  # Death time for prompt candidates
prompt_t_rms_min = 200
prompt_t_rms_max = 500
prompt_nhits_min = 50 #150
prompt_nhits_max = 300
coincidence_window = 150000  # Window for coincidence search
delayed_window = 10  # Window for delayed candidates 
delayed_nhits_min = 10  # Minimum number of hits for delayed candidates
delayed_nhits_max = 50  # Maximum number of hits for delayed candidates

# %%
version = 'v0_5'
#title = f'promptvar_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF' 
#title = f'{version}_prompt100threshold_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF' #Prompt: window 1500ns; nHits [100, 300]; tRMS [200, 500] ns
#title = f'{version}_prompt100threshold_prompt1000window_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF' #Prompt: window 1000ns; nHits [100, 300]; tRMS [200, 500] ns
#title = f'{version}_prompt80threshold_prompt1000window_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF' #Prompt: window 1000ns; nHits [50, 300]; tRMS [200, 500] ns
#title = f'{version}_prompt50threshold_prompt1000window_opentmean_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF'
title = f'{version}_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF'
bkg_file = f'/scratch/halmazan/WCTE/files/AmBeCandidates/neutron_candidates_{bkg_run}_{title}{sig_run}.csv'
sig_file = f'/scratch/halmazan/WCTE/files/AmBeCandidates/neutron_candidates_{sig_run}_{title}.csv'
#acc_file = f'/data/halmazan/WCTE/data/AmBeCandidates/accidental_candidates_{sig_run}_40ns.csv'

df = pd.read_csv(sig_file)
df_bkg = pd.read_csv(bkg_file)
#df_acc = pd.read_csv(acc_file)

#df = df.loc[df.groupby("event_number")["vertex_chi2"].idxmin()].reset_index(drop=True)
#df_bkg = df_bkg.loc[df_bkg.groupby("event_number")["vertex_chi2"].idxmin()].reset_index(drop=True)

#df = df.loc[df.groupby("event_number")["delayed_nhits"].idxmax()].reset_index(drop=True)
#df_bkg = df_bkg.loc[df_bkg.groupby("event_number")["delayed_nhits"].idxmax()].reset_index(drop=True)
#df_acc["DeltaT"] = np.abs(df_acc["vp_delayed_time"]/1000 - df_acc["vp_prompt_time"]/1000)

# %%
deltaR(df, pos)
deltaR(df_bkg, pos)

deltaT(df_bkg)
deltaT(df)

# %%
df
# Out:
#        event_number  prompt_nhits    prompt_time  prompt_trms  prompt_tmean  \
# 0               225            79   94752.038904   240.989905    267.943348
# 1               225            79   94752.038904   240.989905    267.943348
# 2               225            79   94752.038904   240.989905    267.943348
# 3              1152            55  143737.838639   283.062143    367.640804
# 4              1428            51   39982.762887   226.832358    288.158803
# ...             ...           ...            ...          ...           ...
# 13970        100142            58   10073.469699   227.427710    214.114086
# 13971        101604            72  223379.965150   264.262939    277.783338
# 13972        101804            59   33288.301149   233.455031    287.125359
# 13973        101923           192   26498.768944   240.016801    283.065166
# 13974        101923           192   26498.768944   240.016801    283.065166
#
# ...

# %%
df_bkg
# Out:
#       event_number  prompt_nhits    prompt_time  prompt_trms  prompt_tmean  \
# 0             9742            61   68928.365370   283.830753    379.304531
# 1             9742            61   68928.365370   283.830753    379.304531
# 2             9742            61   68928.365370   283.830753    379.304531
# 3             9742            61   68928.365370   283.830753    379.304531
# 4            20887            66    5175.621950   309.812179    348.254931
# ...            ...           ...            ...          ...           ...
# 2018         96610            59  206688.690828   222.142190    324.723603
# 2019         96610            59  206688.690828   222.142190    324.723603
# 2020         96610            59  206688.690828   222.142190    324.723603
# 2021        105964           133   75298.278425   254.893267    353.473643
# 2022        150774            61   76438.744077   355.601025    338.122749
#
# ...

# %%
bkg_summary_file = f'/scratch/halmazan/WCTE/files/AmBeCandidates/summary_{bkg_run}_{title}.csv'
sig_summary_file = f'/scratch/halmazan/WCTE/files/AmBeCandidates/summary_{sig_run}_{title}.csv'

df_summary_bkg = pd.read_csv(bkg_summary_file)
df_summary_sig = pd.read_csv(sig_summary_file)

# %%
bkg_gamma_file = f'/scratch/halmazan/WCTE/files/AmBeCandidates/gamma_candidates_{bkg_run}_{title}.csv'
sig_gamma_file = f'/scratch/halmazan/WCTE/files/AmBeCandidates/gamma_candidates_{sig_run}_{title}.csv'

df_gamma_bkg = pd.read_csv(bkg_gamma_file)
df_gamma = pd.read_csv(sig_gamma_file)

# %%
df_gamma
# Out:
#       event_number      prompt_ti  prompt_nhits  prompt_trms  prompt_tmean  \
# 0              207  222713.082258          59.0   253.937194    288.108296
# 1              225   94752.038904          79.0   240.989905    267.943348
# 2              388    2704.619750         104.0   240.166612    283.685415
# 3              471  197473.156779          73.0   311.643417    356.937415
# 4              500   31847.299377          57.0   242.602643    287.127337
# ...            ...            ...           ...          ...           ...
# 2879        101808  189482.535230          50.0   254.385225    322.653263
# 2880        101824   79788.045912          71.0   280.172542    364.654155
# 2881        101876  144555.473736          61.0   267.673861    330.284482
# 2882        101880   70243.579970          51.0   322.172584    217.672487
# 2883        101923   26498.768944         192.0   240.016801    283.065166
#
#                                        prompt_times_tof  \
# ...

# %%
np.max(df_bkg["event_number"])
# Out:
# np.int64(150774)

# %%
sig_time_windows = [110027, 109645, 89350, 102046]

for tw in sig_time_windows:
    n_expected = tw*270e-6*230 #n/s
    gamma_expected = n_expected * 0.6
    gamma_interacting = gamma_expected*0.6654

    print(f'Time Window: {tw}')
    print(f'Expected Neutrons: {n_expected}')
    print(f'Emitted Gammas: {gamma_expected}')
    print(f'Interacting Gammas: {gamma_interacting}')
# Out:
# Time Window: 110027
# Expected Neutrons: 6832.6767
# Emitted Gammas: 4099.60602
# Interacting Gammas: 2727.877845708
# Time Window: 109645
# Expected Neutrons: 6808.9545
# Emitted Gammas: 4085.3727
# Interacting Gammas: 2718.4069945799997
# Time Window: 89350
# Expected Neutrons: 5548.635
# Emitted Gammas: 3329.181
# Interacting Gammas: 2215.2370374
# Time Window: 102046
# Expected Neutrons: 6337.0566
# Emitted Gammas: 3802.2339599999996
# Interacting Gammas: 2530.0064769839996

# %%
int(df_summary_sig["prompt_candidates"].iloc[0])
# Out:
# 2884

# %%
df = df.loc[df.groupby(["event_number", "prompt_time"])["DeltaR"].idxmin()].reset_index(drop=True)
df_bkg = df_bkg.loc[df_bkg.groupby(["event_number", "prompt_time"])["DeltaR"].idxmin()].reset_index(drop=True)

df = df[(df.delayed_x < 2000) & (df.delayed_x > -2000) & (df.delayed_y < 2000) & (df.delayed_y > -2000) & (df.delayed_z < 2000) & (df.delayed_z > -2000)]
df_bkg = df_bkg[(df_bkg.delayed_x < 2000) & (df_bkg.delayed_x > -2000) & (df_bkg.delayed_y < 2000) & (df_bkg.delayed_y > -2000) & (df_bkg.delayed_z < 2000) & (df_bkg.delayed_z > -2000)]

# %%
df2 = df_gamma.copy()

# use df_gamma["prompt_ti"] instead of ["prompt_time"]
df2["prompt_ti"] = pd.to_numeric(df2["prompt_ti"], errors="coerce")
df2 = df2.dropna(subset=["event_number", "prompt_ti"])

# use unique prompt times per event (common for “how many prompts”)
times = (df2[["event_number", "prompt_ti"]]
         .drop_duplicates()
         .sort_values(["event_number", "prompt_ti"]))

# --- Plot 1: number of prompts per event ---
prompts_per_event = times.groupby("event_number")["prompt_ti"].size()

fig, ax = plt.subplots()
bins1 = np.arange(1, prompts_per_event.max() + 2) - 0.5
ax.hist(prompts_per_event, bins=bins1, lw=2)

ax.set_xlabel("Number of prompts")
ax.set_ylabel("events")
ax.set_title(f"Prompts per TW for Run {sig_run}")
ax.set_xticks(np.arange(1, prompts_per_event.max() + 1))
fig.tight_layout()

# --- Plot 2: time between prompts (events with >= 2 prompts) ---
times = times.copy()
times["dt"] = times.groupby("event_number")["prompt_ti"].diff()

# if prompt_ti is in ns/ps/etc, keep your scaling consistent.
# This mirrors your original: dt/1000
dt = times.loc[times["dt"].notna(), "dt"] / 1000

fig, ax = plt.subplots()
ax.hist(dt, bins=50)

ax.set_xlabel("Time between prompts [mus]")
ax.set_ylabel("Count")
ax.set_title("Time between prompts (events with ≥2 prompts)")
fig.tight_layout()

plt.show()

# %%
df2 = df.copy()

df2["prompt_time"] = pd.to_numeric(df2["prompt_time"], errors="coerce")
df2 = df2.dropna(subset=["event_number", "prompt_time"])

# use unique prompt times per event (common for “how many prompts”)
times = (df2[["event_number", "prompt_time"]]
         .drop_duplicates()
         .sort_values(["event_number", "prompt_time"]))

# --- Plot 1: number of prompts per event ---
prompts_per_event = times.groupby("event_number")["prompt_time"].size()

fig, ax = plt.subplots()
bins1 = np.arange(1, prompts_per_event.max() + 2) - 0.5
ax.hist(prompts_per_event, bins=bins1, lw=2)

ax.set_xlabel("Number of prompts")
ax.set_ylabel("events")
ax.set_title(f"Prompts per TW for Run {sig_run}")
ax.set_xticks(np.arange(1, prompts_per_event.max() + 1))
fig.tight_layout()

# --- Plot 2: time between prompts (events with >= 2 prompts) ---
times = times.copy()
times["dt"] = times.groupby("event_number")["prompt_time"].diff()
dt = times.loc[times["dt"].notna(), "dt"]/1000

fig, ax = plt.subplots()
ax.hist(dt, bins=50)

ax.set_xlabel("Time between prompts [mus]")
ax.set_ylabel("Count")
ax.set_title("Time between prompts (events with ≥2 prompts)")
fig.tight_layout()

plt.show()

# %%
df2 = df.copy()
df2["prompt_time"] = pd.to_numeric(df2["prompt_time"], errors="coerce")
df2 = df2.dropna(subset=["event_number", "prompt_time"])

# unique prompt times per TW (event)
times = (df2[["event_number", "prompt_time"]]
         .drop_duplicates())

# prompts per TW
prompts_per_event = times.groupby("event_number")["prompt_time"].size()

total_candidates = int(prompts_per_event.sum())

# how many TWs have 1,2,3,... prompts
tw_by_nprompts = (prompts_per_event
                  .value_counts()
                  .sort_index()
                  .rename_axis("n_prompts")
                  .rename("n_TW"))

print(total_candidates)
print(tw_by_nprompts)

# (optional) if you want a DataFrame instead of a Series:
tw_by_nprompts_df = tw_by_nprompts.reset_index()
tw_by_nprompts_df.columns = ["n_prompts", "n_TW"]
tw_by_nprompts_df
# Out:
# 1636
# n_prompts
# 1    1322
# 2     131
# 3      16
# 4       1
# Name: n_TW, dtype: int64
#    n_prompts  n_TW
# 0          1  1322
# 1          2   131
# 2          3    16
# 3          4     1

# %%
df2 = df.copy()
df2["prompt_time"] = pd.to_numeric(df2["prompt_time"], errors="coerce")
df2 = df2.dropna(subset=["event_number", "prompt_time"])

# unique prompt times per event = prompt-candidates
times = (df2[["event_number", "prompt_time"]]
         .drop_duplicates()
         .sort_values(["event_number", "prompt_time"]))

# 1) times of ALL prompt candidates (unique per event)
all_candidate_times = times["prompt_time"].to_numpy()

# prompts per event
n_prompts = times.groupby("event_number")["prompt_time"].size()

# 2) times of candidates where the event has ONLY 1 prompt
events_1prompt = n_prompts[n_prompts == 1].index
one_prompt_candidate_times = times.loc[times["event_number"].isin(events_1prompt), "prompt_time"].to_numpy()

# (optional) quick checks
print("Total candidates:", all_candidate_times.size)
print("Candidates from 1-prompt events:", one_prompt_candidate_times.size)
# Out:
# Total candidates: 1636
# Candidates from 1-prompt events: 1322

# %%
def add_numb_prompts(df, event_col="event_number", time_col="prompt_time"):
    df2 = df.copy()

    df2[time_col] = pd.to_numeric(df2[time_col], errors="coerce")
    df2 = df2.dropna(subset=[event_col, time_col])

    # count unique prompt times per event
    prompts_per_event = (df2[[event_col, time_col]]
                         .drop_duplicates()
                         .groupby(event_col)[time_col]
                         .size())

    # write into df (overwrites if already present)
    df["numb_prompts"] = df[event_col].map(prompts_per_event).fillna(0).astype(int)
    return df

# %%
df
# Out:
#       event_number  prompt_nhits    prompt_time  prompt_trms  prompt_tmean  \
# 0              225            79   94752.038904   240.989905    267.943348
# 1             1152            55  143737.838639   283.062143    367.640804
# 2             1428            51   39982.762887   226.832358    288.158803
# 3             1513            65  157963.311728   252.818901    281.873041
# 4             1575            58   58816.738314   211.926283    245.578489
# ...            ...           ...            ...          ...           ...
# 1686        100140            55  145792.507520   270.922199    352.480612
# 1687        100142            58   10073.469699   227.427710    214.114086
# 1688        101604            72  223379.965150   264.262939    277.783338
# 1689        101804            59   33288.301149   233.455031    287.125359
# 1690        101923           192   26498.768944   240.016801    283.065166
#
# ...

# %%
df = add_numb_prompts(df)
df_bkg = add_numb_prompts(df_bkg)

# %%
# Build candidate table (unique prompt per TW/event)
df2 = df.copy()
df2["prompt_time"] = pd.to_numeric(df2["prompt_time"], errors="coerce")
df2 = df2.dropna(subset=["event_number", "prompt_time"])

times = (df2[["event_number", "prompt_time"]]
         .drop_duplicates()
         .sort_values(["event_number", "prompt_time"]))

# number of prompts per event (TW)
n_prompts = times.groupby("event_number")["prompt_time"].size()

# 1) ALL prompt-candidate times (one entry per candidate)
prompt_nhits_bkg = times["prompt_time"].to_numpy()          # or .tolist()

# 2) candidate times for events that have ONLY 1 prompt
one_prompt_events = n_prompts[n_prompts == 1].index
prompt_nhits_bkg2 = times.loc[times["event_number"].isin(one_prompt_events),
                              "prompt_time"].to_numpy()     # or .tolist()

# Signal times (as you already do)
prompt_nhits = df_gamma["prompt_ti"].to_numpy()

# --- plotting (your code) ---
hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(0, 270000))
hist_sig, _ = np.histogram(prompt_nhits, bins=bins_edges)
hist2, _ = np.histogram(prompt_nhits_bkg2, bins=bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label='candidates', color='blue', lw=2, linestyle='--')
plt.step(bins_edges[:-1], hist2, where='post', label='candidates, prompt = 1', color='red', lw=2, linestyle='--')
plt.step(bins_edges[:-1], hist_sig, where='post', label='prompt', color='blue', lw=2)

plt.xlabel('prompt time [ms]')
plt.ylabel('events (a.u.)')
plt.title(f'Prompt Time in TW for Run {sig_run}')
plt.legend()
plt.grid(alpha=0.3)

print(len(prompt_nhits_bkg2))
# Out:
# 1322

# %%
# Group by event_number and keep the row with the maximum delayed_nhits
#df_max_delayed_nhits = df.loc[df.groupby('event_number')['delayed_nhits'].idxmax()]
#df = df_max_delayed_nhits

#df_max_delayed_nhits_bkg = df_bkg.loc[df_bkg.groupby('event_number')['delayed_nhits'].idxmax()]
#df_bkg = df_max_delayed_nhits_bkg

#df_max_delayed_nhits_acc = df_acc.loc[df_acc.groupby('event_number')['vp_delayed_nhits'].idxmax()]
#df_acc = df_max_delayed_nhits_acc

# %%
nBG = 5
deltat_vp = 50000

df['dt'] = 270000 - df['prompt_time']
mask = df['dt'] < (deltat_vp * nBG) 
vp_times_by_event = {}
for event, group in df.loc[mask].groupby('event_number'):
    t0 = group['prompt_time'].iloc[0]   # or use .min() if preferred
    vp_times_by_event[event] = [t0 + j * deltat_vp for j in range(nBG)]

total_vp_times = sum(len(v) for v in vp_times_by_event.values())
print("total vp times:", total_vp_times)
# Out:
# total vp times: 6760

# %%
# --- Input values ---
N_prompts_sig = int(df_summary_sig["prompt_candidates"].iloc[0])
N_prompts_bkg = int(df_summary_bkg["prompt_candidates"].iloc[0])

N_events_sig = np.max(df["event_number"])
N_events_bkg = np.max(df_bkg["event_number"])

N_prompts_cand = N_prompts_sig - N_prompts_bkg*N_events_sig/N_events_bkg

times = (df[["event_number", "prompt_time"]]
         .drop_duplicates()
         .sort_values(["event_number", "prompt_time"]))
N_events_sel_sig = int(times.groupby("event_number")["prompt_time"].size().sum()) #df["event_number"].nunique()

times = (df_bkg[["event_number", "prompt_time"]]
         .drop_duplicates()
         .sort_values(["event_number", "prompt_time"]))
N_events_sel_bkg = int(times.groupby("event_number")["prompt_time"].size().sum()) #df_bkg["event_number"].nunique()

N_events_cand = N_events_sel_sig-N_events_sel_bkg*N_events_sig/N_events_bkg



# --- Statistical uncertainties ---
# Poisson error for counts
err_N_sig = np.sqrt(N_events_sel_sig)
err_N_bkg = np.sqrt(N_events_sel_bkg)
err_N_cand = np.sqrt(N_events_cand)


# --- Create summary table ---
results = {
    f"Run {sig_run}": [
        "Time Windows",
        "Prompt Candidates",
        "Selected Events",
        "Efficiency [%]"
    ],
    "Signal": [
        N_events_sig,
        N_prompts_sig,
        f"{N_events_sel_sig}±{err_N_sig:.1f}",
        N_events_sel_sig*100/N_prompts_sig,
    ],
    "Background": [
        N_events_bkg,
        N_prompts_bkg,
        f"{N_events_sel_bkg}±{err_N_bkg:.1f}",
        N_events_sel_bkg*100/N_prompts_bkg,
    ],
    "Candidates": [
        "-",
        N_prompts_cand,
        f"{N_events_cand:1f}±{err_N_cand:.1f}",
        N_events_cand*100/N_prompts_cand
    ]
}

df_results = pd.DataFrame(results)

# Show nicely
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,3))
ax.axis('off')
tbl = ax.table(
    cellText=df_results.values,
    colLabels=df_results.columns,
    loc='center',
    cellLoc='center'
)
tbl.auto_set_font_size(False)
tbl.set_fontsize(9)
tbl.scale(1.2, 1.2)

plt.show()

n_expected = np.max(df["event_number"])*270e-6*230 #n/s
gamma_expected = n_expected * 0.6 * 0.6653

gamma_efficiency = N_prompts_cand/gamma_expected

print(f'Expected Neutrons: {n_expected}')
print(f'Expected Gammas: {gamma_expected}, gamma selection efficiency {gamma_efficiency*100}%')
# Out:
# Expected Neutrons: 6329.4183
# Expected Gammas: 2526.577196994, gamma selection efficiency 106.46769192672724%

# %%
prompt_nhits = df.delayed_nhits.values
#hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=20, range=(delayed_nhits_min, 29))
hist_sig, bins_edges = np.histogram(prompt_nhits, bins = 25, range=(delayed_nhits_min, delayed_nhits_max))

plt.figure()
plt.hist(df.delayed_nhits.values)
#plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.xlabel('nHits')
plt.ylabel('events (a.u.)')
plt.title('Delayed signal candidates')
plt.legend()
plt.grid(alpha=0.3)

x = prompt_nhits
print("max =", x.max())
print("top edge =", bins_edges[-1])
print("N == top edge:", np.sum(x == bins_edges[-1]))
print("N close to top edge:", np.sum(x >= bins_edges[-2]))
print("N > top edge (dropped):", np.sum(x > bins_edges[-1]))
# Out:
# max = 49
# top edge = 50.0
# N == top edge: 0
# N close to top edge: 1
# N > top edge (dropped): 0
# /tmp/ipykernel_2710148/2829944908.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure()
plt.hist(df.DeltaT.values, bins = 150)
#plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.xlabel('deltaT')
plt.ylabel('events (a.u.)')
plt.title('Delayed signal candidates')
plt.legend()
plt.grid(alpha=0.3)
# Out:
# /tmp/ipykernel_2710148/1232472258.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5), constrained_layout=True)

# 1) nHits histogram (step)
hist_nhits, bins_nhits = np.histogram(df.delayed_nhits.values, bins=20)
axes[0].step(
    bins_nhits[:-1], hist_nhits,
    where="post", label="candidates",
    color="blue", lw=2, linestyle="--"
)
axes[0].set_xlabel("nHits")
axes[0].set_ylabel("events (a.u.)")
axes[0].set_title("Delayed signal candidates")
axes[0].grid(alpha=0.3)

# 2) tRMS histogram (step)
hist_trms, bins_trms = np.histogram(df.delayed_trms_tof.values, bins=30)
axes[1].step(
    bins_trms[:-1], hist_trms,
    where="post", label="candidates",
    color="blue", lw=2, linestyle="--"
)
axes[1].set_xlabel("tRMS [ns]")
axes[1].set_ylabel("events (a.u.)")
axes[1].set_title("Delayed signal candidates")
axes[1].grid(alpha=0.3)

# 3) 2D histogram
h = axes[2].hist2d(
    df.delayed_nhits.values, df.delayed_trms_tof.values,
    bins=20, cmin=0.0001
)
fig.colorbar(h[3], ax=axes[2], label="Density")
axes[2].set_xlabel("nHits")
axes[2].set_ylabel("tRMS [ns]")
axes[2].set_title("Reconstructed Neutron Events")

plt.show()

plt.show()

# %%
plt.hist2d(df.delayed_nhits.values, df.DeltaT.values, bins=50, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.ylabel('deltaT [mus]')
plt.xlabel('nHits')
plt.title(f'{sig_run}')
plt.show()

# %%
print("min/max sig:", prompt_nhits.min(), prompt_nhits.max())
print("min/max bkg:", prompt_nhits_bkg.min(), prompt_nhits_bkg.max())
print("range:", delayed_nhits_min, delayed_nhits_max)
# Out:
# min/max sig: 10 49
# min/max bkg: -5.146319086835561 261960.2543659102
# range: 10 50

# %%
vals, cnt = np.unique(prompt_nhits, return_counts=True)
print(list(zip(vals[-10:], cnt[-10:])))
# Out:
# [(np.int64(40), np.int64(9)), (np.int64(41), np.int64(4)), (np.int64(42), np.int64(3)), (np.int64(43), np.int64(3)), (np.int64(44), np.int64(5)), (np.int64(45), np.int64(1)), (np.int64(46), np.int64(4)), (np.int64(47), np.int64(7)), (np.int64(48), np.int64(2)), (np.int64(49), np.int64(1))]

# %%
cols = ["delayed_x", "delayed_y", "delayed_z"]
labels = ["X [cm]", "Y [cm]", "Z [cm]"]

source_pos = {"delayed_x": pos[0], "delayed_y": pos[1], "delayed_z": pos[2]}

alpha = N_events_bkg / N_events_sig  # scale signal to background exposure

fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharey=True, constrained_layout=True)

for ax, col, label in zip(axes, cols, labels):
    # Drop non-finite
    s = df[col].to_numpy()
    b = df_bkg[col].to_numpy()
    s = s[np.isfinite(s)]
    b = b[np.isfinite(b)]

    # Common bins from combined range
    xmin = np.min([s.min(), b.min()]) if len(s) and len(b) else (s.min() if len(s) else b.min())
    xmax = np.max([s.max(), b.max()]) if len(s) and len(b) else (s.max() if len(s) else b.max())
    bins = np.linspace(xmin, xmax, 26)  # 50 bins

    # Histograms: scale signal counts by alpha via weights
    ax.hist(s, bins=bins, weights=np.full(s.shape, alpha), color="blue", alpha=0.6, label=f'signal')
    ax.hist(b, bins=bins, color="red", alpha=0.6, label=f'background')

    # Source marker line
    vline = source_pos[col]
    ax.axvline(vline, color="k", linestyle="--", linewidth=1.5, label="Source position")

    ax.set_xlabel(label)
    ax.grid(alpha=0.3)
    if(col =='delayed_x'):
        ax.legend()

axes[0].set_ylabel("Events (a.u.)")
fig.suptitle(f"AmBe Run {sig_run} - Delayed Candidates")
plt.show()

# %%
plt.hist2d(df.delayed_trms_tof.values, df.vertex_chi2.values, bins=50, range=[(0,10),(0,100)],  cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 100)
plt.ylabel('chi2/ndf')
plt.xlabel('tRMS [ns]')
plt.title(f'{sig_run}')
plt.show()

# %%
df_gamma
# Out:
#       event_number      prompt_ti  prompt_nhits  prompt_trms  prompt_tmean  \
# 0              207  222713.082258          59.0   253.937194    288.108296
# 1              225   94752.038904          79.0   240.989905    267.943348
# 2              388    2704.619750         104.0   240.166612    283.685415
# 3              471  197473.156779          73.0   311.643417    356.937415
# 4              500   31847.299377          57.0   242.602643    287.127337
# ...            ...            ...           ...          ...           ...
# 2879        101808  189482.535230          50.0   254.385225    322.653263
# 2880        101824   79788.045912          71.0   280.172542    364.654155
# 2881        101876  144555.473736          61.0   267.673861    330.284482
# 2882        101880   70243.579970          51.0   322.172584    217.672487
# 2883        101923   26498.768944         192.0   240.016801    283.065166
#
#                                        prompt_times_tof  \
# ...

# %%
df_gamma_bkg
# Out:
#      event_number      prompt_ti  prompt_nhits  prompt_trms  prompt_tmean  \
# 0            2067  161456.594046          64.0   392.280855    365.341838
# 1            3686    2414.751302          62.0   239.313898    385.947250
# 2            4688     113.448253          51.0   243.715014    367.342639
# 3            4822    1046.775443          56.0   266.723079    345.827841
# 4            6621   52221.005037          61.0   313.662060    386.026213
# ..            ...            ...           ...          ...           ...
# 282        141488  181467.966479          89.0   253.509345    363.973596
# 283        141729  265919.499970          56.0   390.772537    311.917231
# 284        143890      31.562010          50.0   258.357354    362.672312
# 285        150774   76438.593621          61.0   355.530345    338.219357
# 286        151929  165941.879723          95.0   362.735061    219.099863
#
#                                       prompt_times_tof  \
# ...

# %%
def mean_time_window(df):
    s = df["prompt_times"]
    if s.dtype == "object":
        s = s.map(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

    tmp = df[["event_number"]].copy()
    tmp["prompt_times"] = s
    tmp = tmp.explode("prompt_times", ignore_index=False)

    tmp["prompt_times"] = pd.to_numeric(tmp["prompt_times"], errors="coerce")

    g = tmp.groupby("event_number")["prompt_times"]
    t_c = g.mean() - g.min()

    t_c_list = t_c.to_list()
    t_c_list = [x for x in t_c_list]
    return t_c_list

def mean_time_window_by_index(df):
    s = df["prompt_times"]
    if s.dtype == "object":
        s = s.map(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

    tmp = pd.DataFrame(index=df.index)
    tmp["prompt_times"] = s

    tmp = tmp.explode("prompt_times", ignore_index=False)
    tmp["prompt_times"] = pd.to_numeric(tmp["prompt_times"], errors="coerce")

    g = tmp.groupby(tmp.index)["prompt_times"]
    t_c = g.mean() - g.min()

    return (t_c).to_list()

#t_c_list_cand = mean_time_window_by_index(df)
#t_c_list_bkg_cand = mean_time_window_by_index(df_bkg)
#t_c_list_prompt = mean_time_window_by_index(df_gamma)
#t_c_list_bkg_prompt = mean_time_window_by_index(df_gamma_bkg)

# %%
df
# Out:
#       event_number  prompt_nhits    prompt_time  prompt_trms  prompt_tmean  \
# 0              225            79   94752.038904   240.989905    267.943348
# 1             1152            55  143737.838639   283.062143    367.640804
# 2             1428            51   39982.762887   226.832358    288.158803
# 3             1513            65  157963.311728   252.818901    281.873041
# 4             1575            58   58816.738314   211.926283    245.578489
# ...            ...           ...            ...          ...           ...
# 1686        100140            55  145792.507520   270.922199    352.480612
# 1687        100142            58   10073.469699   227.427710    214.114086
# 1688        101604            72  223379.965150   264.262939    277.783338
# 1689        101804            59   33288.301149   233.455031    287.125359
# 1690        101923           192   26498.768944   240.016801    283.065166
#
# ...

# %%
df_gamma
# Out:
#       event_number      prompt_ti  prompt_nhits  prompt_trms  prompt_tmean  \
# 0              207  222713.082258          59.0   253.937194    288.108296
# 1              225   94752.038904          79.0   240.989905    267.943348
# 2              388    2704.619750         104.0   240.166612    283.685415
# 3              471  197473.156779          73.0   311.643417    356.937415
# 4              500   31847.299377          57.0   242.602643    287.127337
# ...            ...            ...           ...          ...           ...
# 2879        101808  189482.535230          50.0   254.385225    322.653263
# 2880        101824   79788.045912          71.0   280.172542    364.654155
# 2881        101876  144555.473736          61.0   267.673861    330.284482
# 2882        101880   70243.579970          51.0   322.172584    217.672487
# 2883        101923   26498.768944         192.0   240.016801    283.065166
#
#                                        prompt_times_tof  \
# ...

# %%
def add_t_c_column(df, source_col="prompt_times", target_col="t_c"):
    s = df[source_col]

    # parse strings like "[1, 2, 3]" into actual lists
    if s.dtype == "object":
        s = s.map(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

    tmp = pd.DataFrame({source_col: s}, index=df.index)

    # one value per row while keeping original index
    tmp = tmp.explode(source_col, ignore_index=False)
    tmp[source_col] = pd.to_numeric(tmp[source_col], errors="coerce")

    g = tmp.groupby(level=0)[source_col]
    t_c = g.mean() - g.min()          # this is a Series indexed by df.index

    df[target_col] = t_c              # aligns by index automatically
    return df

#add_t_c_column(df_gamma)
#add_t_c_column(df_gamma_bkg)
#add_t_c_column(df)
#add_t_c_column(df_bkg)

# %%
df_gamma
# Out:
#       event_number      prompt_ti  prompt_nhits  prompt_trms  prompt_tmean  \
# 0              207  222713.082258          59.0   253.937194    288.108296
# 1              225   94752.038904          79.0   240.989905    267.943348
# 2              388    2704.619750         104.0   240.166612    283.685415
# 3              471  197473.156779          73.0   311.643417    356.937415
# 4              500   31847.299377          57.0   242.602643    287.127337
# ...            ...            ...           ...          ...           ...
# 2879        101808  189482.535230          50.0   254.385225    322.653263
# 2880        101824   79788.045912          71.0   280.172542    364.654155
# 2881        101876  144555.473736          61.0   267.673861    330.284482
# 2882        101880   70243.579970          51.0   322.172584    217.672487
# 2883        101923   26498.768944         192.0   240.016801    283.065166
#
#                                        prompt_times_tof  \
# ...

# %%
len(df_gamma.prompt_ti.values), len(df.prompt_time.values)
# Out:
# (2884, 1636)

# %%
prompt_nhits = df_gamma.prompt_ti.values
prompt_nhits_bkg = df.prompt_time.unique()

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(0, 270000))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'candidates', color='blue', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig , where='post', label=f'prompt', color='blue', lw=2)
plt.xlabel('prompt time [ms]')
plt.ylabel('events (a.u.)')
plt.title(f'Prompt Time in TW for Run {sig_run}')
#plt.yscale('log') 
plt.legend()
plt.grid(alpha=0.3)
#print(hist_sig)

# %%
prompt_nhits = df_gamma.prompt_ti.values
prompt_nhits_bkg = df.prompt_time.unique()

# --- histograms (same binning) ---
hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(0, 270000))
hist_sig, _      = np.histogram(prompt_nhits,     bins=bins_edges)  # prompt

# --- ratio (cand / prompt), in percent ---
ratio = np.divide(
    hist.astype(float),
    hist_sig.astype(float),
    out=np.full_like(hist, np.nan, dtype=float),
    where=(hist_sig != 0)
) * 100.0

# Simple propagated error assuming Poisson counts in both:
# r = (A/B)*100 ;  σ_r/r = sqrt( (σA/A)^2 + (σB/B)^2 ) with σA=sqrt(A), σB=sqrt(B)
A = hist.astype(float)      # candidates
B = hist_sig.astype(float)  # prompt
ratio_err = np.full_like(ratio, np.nan, dtype=float)
mask = (A > 0) & (B > 0)
ratio_err[mask] = ratio[mask] * np.sqrt(1.0 / A[mask] + 1.0 / B[mask])

# x coordinates for "post" steps
x = bins_edges[:-1]

# --- figure with ratio panel ---
fig, (ax, rax) = plt.subplots(
    2, 1, sharex=True,
    gridspec_kw={"height_ratios": [3, 1], "hspace": 0.05},
    figsize=(7, 6)
)

# top
ax.step(x, hist, where="post", label="candidates", color="blue", lw=2, linestyle="--")
ax.step(x, hist_sig, where="post", label="prompt", color="blue", lw=2)
ax.set_ylabel("events (a.u.)")
ax.set_title(f"Prompt Time in TW for Run {sig_run}")
ax.legend()
ax.grid(alpha=0.3)

# bottom ratio
#rax.axhline(60.0,  color="red",   lw=2, alpha=0.9, ls="--")     # 60% reference line
rax.step(x, ratio, where="post", color="blue", lw=2)

# optional: ratio error bars at bin centers
centers = 0.5 * (bins_edges[:-1] + bins_edges[1:])
rax.errorbar(centers, ratio, yerr=ratio_err, fmt="none", ecolor="blue", elinewidth=1, alpha=0.7)

rax.set_xlabel("prompt time [ms]")
rax.set_ylabel("ratio (%)")
rax.set_ylim(0, 100)# np.nanmax(ratio) * 1.2 if np.isfinite(np.nanmax(ratio)) else 200)
rax.grid(alpha=0.3)

plt.show()

# %%
prompt_nhits = df_gamma_bkg.prompt_ti.values
prompt_nhits_bkg = df_bkg.prompt_time.unique()

# --- histograms (same binning) ---
hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(0, 270000))
hist_sig, _      = np.histogram(prompt_nhits,     bins=bins_edges)  # prompt

# --- ratio (cand / prompt), in percent ---
ratio = np.divide(
    hist.astype(float),
    hist_sig.astype(float),
    out=np.full_like(hist, np.nan, dtype=float),
    where=(hist_sig != 0)
) * 100.0

# Simple propagated error assuming Poisson counts in both:
# r = (A/B)*100 ;  σ_r/r = sqrt( (σA/A)^2 + (σB/B)^2 ) with σA=sqrt(A), σB=sqrt(B)
A = hist.astype(float)      # candidates
B = hist_sig.astype(float)  # prompt
ratio_err = np.full_like(ratio, np.nan, dtype=float)
mask = (A > 0) & (B > 0)
ratio_err[mask] = ratio[mask] * np.sqrt(1.0 / A[mask] + 1.0 / B[mask])

# x coordinates for "post" steps
x = bins_edges[:-1]

# --- figure with ratio panel ---
fig, (ax, rax) = plt.subplots(
    2, 1, sharex=True,
    gridspec_kw={"height_ratios": [3, 1], "hspace": 0.05},
    figsize=(7, 6)
)

# top
ax.step(x, hist, where="post", label="candidates", color="red", lw=2, linestyle="--")
ax.step(x, hist_sig, where="post", label="prompt", color="red", lw=2)
ax.set_ylabel("events (a.u.)")
ax.set_title(f"Prompt Time in TW for Run {bkg_run}")
ax.legend()
ax.grid(alpha=0.3)

# bottom ratio
#rax.axhline(60.0,  color="red",   lw=2, alpha=0.9, ls="--")     # 60% reference line
rax.step(x, ratio, where="post", color="red", lw=2)

# optional: ratio error bars at bin centers
centers = 0.5 * (bins_edges[:-1] + bins_edges[1:])
rax.errorbar(centers, ratio, yerr=ratio_err, fmt="none", ecolor="red", elinewidth=1, alpha=0.7)

rax.set_xlabel("prompt time [ms]")
rax.set_ylabel("ratio (%)")
rax.set_ylim(0, 100)# np.nanmax(ratio) * 1.2 if np.isfinite(np.nanmax(ratio)) else 200)
rax.grid(alpha=0.3)

plt.show()

# %%
plt.hist2d(df.prompt_time.values, df.DeltaT.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
plt.xlim(0, 270000)  # Set x-axis limits
plt.ylim(0, 150)
plt.ylabel('tcapt [mus]')
plt.xlabel('prompt time [ms]')
plt.title(f'{sig_run}')
plt.show()

# %%
n_events_per_tw = df.groupby("event_number")["event_number"].transform("size")

plt.hist2d(
    df["prompt_time"].to_numpy(),
    n_events_per_tw.to_numpy(),
    bins=[20, 10],
    cmin=0.0001
)
plt.colorbar(label="Counts")  # hist2d returns counts per bin (not a probability density unless density=True)
plt.xlim(0, 270000)
plt.ylim(1, 11)
plt.ylabel("number of events per TW")
plt.xlabel("prompt time [ms]")
plt.title(f"{sig_run}")
plt.show()

# %%
n_events_per_tw = df.groupby("event_number")["event_number"].transform("size")
n_prompts_per_tw = df_gamma.groupby("event_number")["prompt_ti"].transform("size")

len(n_prompts_per_tw), len(n_events_per_tw)
# Out:
# (2884, 1636)

# %%
n_prompts_per_tw = df_gamma.groupby("event_number")["prompt_ti"].transform("size")

plt.hist2d(
    df_gamma["prompt_ti"].to_numpy(),
    n_prompts_per_tw.to_numpy(),
    bins=[20, 10],
    cmin=0.0001
)
plt.colorbar(label="Counts")  # hist2d returns counts per bin (not a probability density unless density=True)
plt.xlim(0, 270000)
#plt.ylim(1, 11)
plt.ylabel("number of prompts per TW")
plt.xlabel("prompt time [ms]")
plt.title(f"{sig_run}")
plt.show()

# %%
counts = df["event_number"].value_counts().sort_index().values

counts
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(1470,))

# %%
dup_events = df_gamma.loc[df_gamma["event_number"].duplicated(keep=False), "event_number"].unique()
multi = (
    df_gamma[df_gamma["event_number"].duplicated(keep=False)]
    .sort_values(["event_number", "prompt_ti"])
    .copy()
)

# difference in prompt_ti between consecutive rows in the same event_number
multi["dt_prompt_ti"] = multi.groupby("event_number")["prompt_ti"].diff()

multi["dt_prompt_ti"] = (
    multi.groupby("event_number")["prompt_ti"]
         .diff()
         .fillna(0)
)

multi[["event_number", "prompt_ti", "dt_prompt_ti"]]
# Out:
#       event_number      prompt_ti   dt_prompt_ti
# 50            3596   91807.725545       0.000000
# 51            3596  237858.244674  146050.519128
# 170          10982  176316.534170       0.000000
# 171          10982  211099.963460   34783.429291
# 215          11262  135803.192995       0.000000
# ...            ...            ...            ...
# 2830        100018  126715.196182   65996.531228
# 2831        100019   75593.226767       0.000000
# 2832        100019  198316.132359  122722.905592
# 2838        100039  124582.332719       0.000000
# 2839        100039  184799.437545   60217.104825
#
# [365 rows x 3 columns]

# %%
deltaTtimes = multi[multi.dt_prompt_ti>0.0].dt_prompt_ti.values/1000

hist, bins_edges = np.histogram(deltaTtimes, bins=25, range=(0, 270))

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'candidates', color='blue', lw=2, linestyle = '--')
#plt.step(bins_edges[:-1], hist_sig , where='post', label=f'prompt', color='blue', lw=2)
#plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('prompt time (ms)')
plt.ylabel('events (a.u.)')
plt.title('Prompt Time in TW')
#plt.yscale('log') 
plt.legend()
plt.grid(alpha=0.3)

# %%
plt.hist2d(df.prompt_time.values, df.DeltaT.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
plt.xlim(0, 270000)  # Set x-axis limits
plt.ylim(0, 150)
plt.ylabel('tcapt [mus]')
plt.xlabel('prompt time [ms]')
plt.title(f'{sig_run}')
plt.show()

# %%
def plot_combined_hist_max100(
    df,
    event_col="event_number",      # change if needed
    times_col="prompt_times",
    max_events=100,
    bins=30,
    pick="most_frequent",          # "most_frequent" | "first" | "random"
    random_state=0,
    density=False
):
    # Parse prompt_times if they are stringified lists
    s = df[times_col]
    if s.dtype == "object":
        s = s.map(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

    tmp = pd.DataFrame({event_col: df[event_col].values, times_col: s}, index=df.index)
    tmp = tmp.explode(times_col, ignore_index=False)
    tmp[times_col] = pd.to_numeric(tmp[times_col], errors="coerce")
    tmp = tmp.dropna(subset=[times_col])

    # Rebase within each original row (first element becomes 0)
    tmp["t_rel"] = tmp[times_col] - tmp.groupby(level=0)[times_col].transform("min")

    # Pick up to 100 event labels
    if pick == "most_frequent":
        selected = tmp[event_col].value_counts().index[:max_events].to_list()
    elif pick == "first":
        selected = tmp[event_col].drop_duplicates().head(max_events).to_list()
    elif pick == "random":
        selected = (
            tmp[event_col].drop_duplicates()
            .sample(n=min(max_events, tmp[event_col].nunique()), random_state=random_state)
            .to_list()
        )
    else:
        raise ValueError("pick must be one of: 'most_frequent', 'first', 'random'")

    pooled = tmp.loc[tmp[event_col].isin(selected), "t_rel"]

    plt.figure(figsize=(10, 5))
    plt.hist(pooled, bins=bins, density=density)
    plt.title(f"Combined prompt_times distribution (rebased), {len(selected)} events")
    plt.xlabel("prompt_times rebased (t - t0)")
    plt.ylabel("density" if density else "count")
    plt.tight_layout()
    plt.show()

    return pooled  # useful if you want to inspect / compute stats

# %%
if sig_run == '2385':
    def string_to_array(array_string):
        if isinstance(array_string, str):
            return np.fromstring(array_string.strip('[]'), dtype=int, sep=' ')
        return array_string  # in case it's already an array

    df['prompt_mpmt'] = df['prompt_mpmt'].apply(string_to_array)
    df['prompt_pmt'] = df['prompt_pmt'].apply(string_to_array)
    df_bkg['prompt_mpmt'] = df_bkg['prompt_mpmt'].apply(string_to_array)
    df_bkg['prompt_pmt'] = df_bkg['prompt_pmt'].apply(string_to_array)

# %%
np.mean(df.prompt_nhits)
# Out:
# np.float64(62.062958435207825)

# %%
prompt_nhits = df.prompt_nhits.values
prompt_nhits_bkg = df_bkg.prompt_nhits.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=50, range=(30, 300))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('nHits')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
#plt.yscale('log') 
plt.legend()
plt.grid(alpha=0.3)

# %%
plt.figure()
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('nHits')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
#plt.yscale('log') 
plt.legend()
plt.grid(alpha=0.3)

# %%
plt.hist2d(df.prompt_nhits.values, df.prompt_tmean.values, bins=50, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.xlabel('nHits')
plt.ylabel('tmean [ns]')
plt.title(f'{sig_run}')
plt.show()

# %%
plt.hist2d(df_bkg.prompt_nhits.values, df_bkg.prompt_tmean.values, bins=50, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.xlabel('nHits')
plt.ylabel('tmean [ns]')
plt.title(f'{bkg_run}')
plt.show()

# %%
prompt_nhits = df_gamma.prompt_trms.values
prompt_nhits_bkg = df_gamma_bkg.prompt_trms.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(200, 500))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('tRMS [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
# tRMS arrays
prompt_trms_bkg = df_bkg['prompt_trms'].to_numpy()
prompt_trms_sig = df_gamma['prompt_trms'].to_numpy()   # signal now from df_gamma

# Base binning from background
hist_bkg, bins_edges = np.histogram(prompt_trms_bkg, bins=30, range=(200, 500))

# nhits ranges to highlight (from df_gamma.prompt_nhits)
nhits_ranges = [(50, 60), (60, 70), (70, 80), (90, 100), (100, 300)]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#9467bd', '#8c564b']

scale = N_events_bkg / N_events_sig  # keep your normalization convention

plt.figure(figsize=(9,6))

# Background
plt.step(
    bins_edges[:-1], hist_bkg, where='post',
    label=f'background - run {bkg_run}', color='red', lw=2, linestyle='--'
)

# Signal contributions by nhits range (using df_gamma)
hist_sig_total = np.zeros_like(hist_bkg, dtype=float)

for (lo, hi), c in zip(nhits_ranges, colors):
    sel = (df_gamma['prompt_nhits'] >= lo) & (df_gamma['prompt_nhits'] < hi)
    h_slice, _ = np.histogram(df_gamma.loc[sel, 'prompt_trms'].to_numpy(), bins=bins_edges)
    h_slice = h_slice * scale
    hist_sig_total += h_slice

    plt.stairs(
        h_slice, bins_edges, fill=True, alpha=0.25, color=c,
        label=f'gamma nhits [{lo},{hi})'
    )

# Total signal (df_gamma)
plt.step(
    bins_edges[:-1], hist_sig_total, where='post',
    color='blue', lw=2, label=f'prompt - run {sig_run}'
)

plt.xlabel('tRMS [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
plt.legend(fontsize=9, ncol=2)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
prompt_nhits = df.prompt_trms.unique()
prompt_nhits_bkg = df_bkg.prompt_trms.unique()

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=30, range=(200, 500))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('tRMS [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
prompt_nhits = df.prompt_tmean.unique()
prompt_nhits_bkg = df_bkg.prompt_tmean.unique()

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=30, range=(200, 400))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('t_Mean [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
# build ratio
ratio_sig = (df["prompt_trms"] / df["prompt_tmean"]).to_numpy()
ratio_bkg = (df_bkg["prompt_trms"] / df_bkg["prompt_tmean"]).to_numpy()

# remove bad values
ratio_sig = ratio_sig[np.isfinite(ratio_sig)]
ratio_bkg = ratio_bkg[np.isfinite(ratio_bkg)]

# choose binning
bins_edges = np.linspace(0, 4, 50)

hist_bkg, bins_edges = np.histogram(ratio_bkg, bins=bins_edges)
hist_sig, _ = np.histogram(ratio_sig, bins=bins_edges)

# scale signal to background statistics
scale = N_events_bkg / N_events_sig

plt.figure(figsize=(8,6))
plt.step(bins_edges[:-1], hist_bkg, where='post',
         label=f'background - run {bkg_run}',
         color='red', lw=2, linestyle='--')

plt.step(bins_edges[:-1], hist_sig * scale, where='post',
         label=f'signal - run {sig_run}',
         color='blue', lw=2)

#plt.step(bins_edges[:-1], hist_sig * scale - hist_bkg, where='post',
#         linewidth=2, color='green', label='signal - bkg')

plt.xlabel(r'$t_{\mathrm{RMS}} / t_{\mathrm{Mean}}$')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Build variable
var_sig = (df["prompt_nhits"] / df["prompt_trms"]).to_numpy()
var_bkg = (df_bkg["prompt_nhits"] / df_bkg["prompt_trms"]).to_numpy()

# Clean bad values
var_sig = var_sig[np.isfinite(var_sig)]
var_bkg = var_bkg[np.isfinite(var_bkg)]

# Common binning
xmin = min(var_sig.min(), var_bkg.min())
xmax = max(var_sig.max(), var_bkg.max())

bins_edges = np.linspace(xmin, xmax, 60)

hist_bkg, bins_edges = np.histogram(var_bkg, bins=bins_edges)
hist_sig, _ = np.histogram(var_sig, bins=bins_edges)

# Scale signal to same exposure/statistics as background
scale = N_events_bkg / N_events_sig

plt.figure(figsize=(9, 7))

plt.step(bins_edges[:-1], hist_bkg, where='post',
         label=f'background - run {bkg_run}',
         color='red', lw=2, linestyle='--')

plt.step(bins_edges[:-1], hist_sig * scale, where='post',
         label=f'signal - run {sig_run}',
         color='blue', lw=2)

plt.step(bins_edges[:-1], hist_sig * scale - hist_bkg, where='post',
         linewidth=2, color='green', label='signal - bkg')

plt.xlabel('nHits/tRMS')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
x = df["prompt_trms"].values / df["prompt_tmean"].values   # tRMS / tMean
y = df["prompt_trms"].values                                # tRMS

mask = np.isfinite(x) & np.isfinite(y) & (df["prompt_tmean"].values != 0)

x = x[mask]
y = y[mask]

plt.figure(figsize=(8,6))
plt.hist2d(x, y, bins=50, cmin=1)
plt.colorbar(label='Counts')
plt.xlabel(r'$t_{\mathrm{RMS}}/t_{\mathrm{Mean}}$')
plt.ylabel(r'$t_{\mathrm{RMS}}$ [ns]')
plt.title(f'{sig_run}')
plt.tight_layout()
plt.show()

# %%
plt.hist2d(df.prompt_tmean.values, df.prompt_trms.values, bins=50, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.xlabel('t_Mean [ns]')
plt.ylabel('tRMS [ns]')
plt.title(f'{sig_run}')
plt.show()

# %%
plt.hist2d(df_gamma.prompt_tmean.values, df_gamma.prompt_trms.values, bins=50, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.xlabel('t_Mean [ns]')
plt.ylabel('tRMS [ns]')
plt.title(f'{sig_run}')
plt.show()


plt.hist2d(df_gamma_bkg.prompt_tmean.values, df_gamma_bkg.prompt_trms.values, bins=50, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.xlabel('t_Mean [ns]')
plt.ylabel('tRMS [ns]')
plt.title(f'{bkg_run}')
plt.show()

# %%
df_gamma_clean = df_gamma
df_gamma_bkg_clean = df_gamma_bkg

df_gamma_clean.event_number.nunique(), df_gamma_bkg_clean.event_number.nunique()
# Out:
# (2692, 266)

# %%
prompt_nhits = df_gamma.prompt_trms.unique()
prompt_nhits_bkg = df_gamma_bkg.prompt_trms.unique()

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(prompt_t_rms_min, prompt_t_rms_max))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
#plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'no tmean cut')


prompt_nhits = df_gamma_clean.prompt_trms.unique()
prompt_nhits_bkg = df_gamma_bkg_clean.prompt_trms.unique()

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(prompt_t_rms_min, prompt_t_rms_max))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'with tmean [200, 400]ns', linestyle = '-')
plt.xlabel('tRMS [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
#plt.legend()
plt.grid(alpha=0.3)

# %%
events = df_gamma["prompt_times_tof"].values

def to_numeric_array(ev):
    # already array-like numeric
    if isinstance(ev, np.ndarray):
        return ev.astype(float)
    if isinstance(ev, (list, tuple)):
        return np.asarray(ev, dtype=float)

    # string case: "[1.2, 3.4, 5.6]"
    if isinstance(ev, str):
        ev = ev.strip()
        try:
            return np.asarray(ast.literal_eval(ev), dtype=float)
        except Exception:
            # fallback for badly formatted whitespace-separated strings
            ev = ev.strip("[]")
            return np.fromstring(ev, sep=",", dtype=float)

    # final fallback
    return np.asarray(ev, dtype=float)

shifted = []
for ev in events:
    arr = to_numeric_array(ev)
    if arr.size == 0:
        continue
    arr = np.sort(arr)          # optional but recommended
    arr = arr - arr[0]          # set first hit to 0
    shifted.append(arr)

all_shifted_hit_times = np.concatenate(shifted)



events_clean = df_gamma_clean["prompt_times_tof"].values

shifted_clean = []
for ev in events_clean:
    arr = to_numeric_array(ev)
    if arr.size == 0:
        continue
    arr = np.sort(arr)          # optional but recommended
    arr = arr - arr[0]          # set first hit to 0
    shifted_clean.append(arr)

all_shifted_hit_times_clean = np.concatenate(shifted_clean)

plt.figure(figsize=(10, 6))
plt.hist(all_shifted_hit_times, bins=150, range=(0, 1000), label=f'no tmean cut')
plt.hist(all_shifted_hit_times_clean, bins=150, range=(0, 1000), label=f'with tmean [200, 400]ns')
plt.xlabel("Prompt hit time since first hit [ns]")
plt.ylabel("Count")
plt.title("All prompt hit-times combined")
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
plt.hist2d(df_gamma_bkg_clean.prompt_nhits.values, df_gamma_bkg_clean.prompt_trms.values, bins=50, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.xlabel('nHits')
plt.ylabel('tRMS [ns]')
plt.title(f'{bkg_run}')
plt.show()

# %%
prompt_nhits = df_gamma.prompt_nhits.values
prompt_nhits_bkg = df_gamma_bkg.prompt_nhits.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=30, range=(75, 300))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'no tmean cut')

prompt_nhits = df_gamma_clean.prompt_nhits.values
prompt_nhits_bkg = df_gamma_bkg_clean.prompt_nhits.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=30, range=(75, 300))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)


#plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'with tmean [200, 400]ns', linestyle = '--')
plt.xlabel('nHits')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
#plt.yscale('log') 
#plt.legend()
plt.grid(alpha=0.3)

# %%
prompt_nhits = df_gamma_clean.prompt_nhits.values
prompt_nhits_bkg = df_gamma_bkg_clean.prompt_nhits.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=30, range=(30, 300))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('nHits')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates  - with tmean [200, 400]ns')
#plt.yscale('log') 
plt.legend()
plt.grid(alpha=0.3)

# %%
prompt_nhits = df_gamma.prompt_trms.unique()
prompt_nhits_bkg = df_gamma_bkg.prompt_trms.unique()

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(prompt_t_rms_min, prompt_t_rms_max))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'prompt')


prompt_nhits = df.prompt_trms.unique()
prompt_nhits_bkg = df_bkg.prompt_trms.unique()

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(prompt_t_rms_min, prompt_t_rms_max))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'candidate', linestyle = '--')
plt.xlabel('tRMS [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
prompt_nhits = df_gamma.prompt_tmean.unique()

hist, bins_edges = np.histogram(prompt_nhits, bins=25)

plt.figure()
plt.step(bins_edges[:-1], hist , where='post', label=f'signal - MC', color='blue', lw=2)
plt.xlabel('t_Mean [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
prompt_nhits = df_gamma.prompt_nhits.values
prompt_nhits_bkg = df_gamma_bkg.prompt_nhits.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=50, range=(30, 300))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('nHits')
plt.ylabel('events (a.u.)')
plt.title('Prompt signal candidates')
#plt.yscale('log') 
plt.legend()
plt.grid(alpha=0.3)

# %%
events = df_gamma["prompt_times_tof"].values

def to_numeric_array(ev):
    # already array-like numeric
    if isinstance(ev, np.ndarray):
        return ev.astype(float)
    if isinstance(ev, (list, tuple)):
        return np.asarray(ev, dtype=float)

    # string case: "[1.2, 3.4, 5.6]"
    if isinstance(ev, str):
        ev = ev.strip()
        try:
            return np.asarray(ast.literal_eval(ev), dtype=float)
        except Exception:
            # fallback for badly formatted whitespace-separated strings
            ev = ev.strip("[]")
            return np.fromstring(ev, sep=",", dtype=float)

    # final fallback
    return np.asarray(ev, dtype=float)

shifted = []
for ev in events:
    arr = to_numeric_array(ev)
    if arr.size == 0:
        continue
    arr = np.sort(arr)          # optional but recommended
    arr = arr - arr[0]          # set first hit to 0
    shifted.append(arr)

all_shifted_hit_times = np.concatenate(shifted)

plt.figure(figsize=(10, 6))
plt.hist(all_shifted_hit_times, bins=150, range=(0, 1000))
plt.xlabel("Prompt hit time since first hit [ns]")
plt.ylabel("Count")
plt.title("All prompt hit-times combined")
plt.grid(alpha=0.3)
plt.show()

# %%
def to_numeric_array(ev):
    if isinstance(ev, np.ndarray):
        return ev.astype(float)
    if isinstance(ev, (list, tuple)):
        return np.asarray(ev, dtype=float)
    if isinstance(ev, str):
        ev = ev.strip()
        try:
            return np.asarray(ast.literal_eval(ev), dtype=float)
        except Exception:
            ev = ev.strip("[]")
            return np.fromstring(ev, sep=",", dtype=float)
    return np.asarray(ev, dtype=float)

def get_shifted_times(df, col="prompt_times_raw", tmax=1500, sort_hits=True):
    shifted_all = []

    for ev in df[col].dropna().values:
        arr = to_numeric_array(ev)
        if arr.size == 0:
            continue

        if sort_hits:
            arr = np.sort(arr)

        arr = arr - arr[0]   # first hit -> 0

        # keep only hits inside prompt window
        arr = arr[(arr >= 0) & (arr <= tmax)]

        if arr.size > 0:
            shifted_all.append(arr)

    if not shifted_all:
        return np.array([])

    return np.concatenate(shifted_all)

# Get combined shifted hit times
sig_times = get_shifted_times(df_gamma_clean, col="prompt_times_tof", tmax=1500)
bkg_times = get_shifted_times(df_gamma_bkg_clean, col="prompt_times_tof", tmax=1500)

# Common binning
bins = np.linspace(0, 1000, 50)   # 25 bins of 60 ns each

sig_counts, edges = np.histogram(sig_times, bins=bins)
bkg_counts, _     = np.histogram(bkg_times, bins=bins)

sub_counts = sig_counts - bkg_counts

# Plot
plt.figure()

plt.step(edges[:-1], bkg_counts, where='post',
         color='red', linestyle='--', linewidth=2,
         label='background')

plt.step(edges[:-1], sig_counts, where='post',
         color='blue', linewidth=2,
         label='signal')

#plt.step(edges[:-1], sub_counts, where='post',
#         color='green', linewidth=2,
#         label='signal - bkg')

plt.xlabel('Hit time since first hit [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt hit-time distribution')
plt.xlim(0, 1000)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure()
plt.step(edges[:-1], sub_counts, where='post',
         color='green', linewidth=2,
         label='signal - bkg')

plt.xlabel('Hit time since first hit [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt hit-time distribution')
plt.xlim(0, 1000)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()


def expo(t, A, tau):
    return A * np.exp(-t / tau)

bin_centers = 0.5 * (edges[:-1] + edges[1:])
fit_mask = (bin_centers >= 20) & (bin_centers <= 1500) & (sub_counts > 0)

x_fit = bin_centers[fit_mask]
y_fit = sub_counts[fit_mask]

# initial guesses
p0 = [y_fit.max(), 300]

# fit
popt, pcov = curve_fit(expo, x_fit, y_fit, p0=p0)
A_fit, tau_fit = popt
A_err, tau_err = np.sqrt(np.diag(pcov))

# smooth curve for plotting
x_smooth = np.linspace(0, 1000, 500)
y_smooth = expo(x_smooth, A_fit, tau_fit)

# Plot
plt.figure()

plt.step(edges[:-1], sub_counts, where='post',
         color='green', linewidth=2,
         label='signal - bkg')

plt.plot(x_smooth, y_smooth,
         color='black', linestyle='--', linewidth=2,
         label=fr'Exp fit: $A e^{{-t/\tau}}$, $\tau = {tau_fit:.1f} \pm {tau_err:.1f}$ ns')

plt.xlabel('Hit time since first hit [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt hit-time distribution')
plt.xlim(0, 1000)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

print(f"A   = {A_fit:.3f} ± {A_err:.3f}")
print(f"tau = {tau_fit:.3f} ± {tau_err:.3f} ns")
# Out:
# A   = 7221.869 ± 158.570
# tau = 490.750 ± 16.473 ns

# %%
def expo(t, A, tau):
    return A * np.exp(-t / tau)

def expo_shifted(t, A, tau, t0):
    return A * np.exp(-(t - t0) / tau)

bin_centers = 0.5 * (edges[:-1] + edges[1:])

# -----------------------
# User-defined limits
# -----------------------
tmin = 20
tlim = 450     # split point between fast and slow components
tmax = 1000

# -----------------------
# Define masks
# -----------------------
fast_mask = (bin_centers >= tmin) & (bin_centers <= tlim) & (sub_counts > 0)
slow_mask = (bin_centers >= tlim) & (bin_centers <= tmax) & (sub_counts > 0)

x_fast = bin_centers[fast_mask]
y_fast = sub_counts[fast_mask]

x_slow = bin_centers[slow_mask]
y_slow = sub_counts[slow_mask]

# -----------------------
# Initial guesses
# -----------------------
p0_fast = [y_fast.max(), 100]
p0_slow = [y_slow.max(), 500]

# -----------------------
# Fits
# -----------------------
popt_fast, pcov_fast = curve_fit(expo, x_fast, y_fast, p0=p0_fast)
A_fast, tau_fast = popt_fast
A_fast_err, tau_fast_err = np.sqrt(np.diag(pcov_fast))

# slow fit anchored at tlim for easier interpretation
def expo_slow(t, A, tau):
    return expo_shifted(t, A, tau, tlim)

popt_slow, pcov_slow = curve_fit(expo_slow, x_slow, y_slow, p0=p0_slow)
A_slow, tau_slow = popt_slow
A_slow_err, tau_slow_err = np.sqrt(np.diag(pcov_slow))

# -----------------------
# Smooth curves
# -----------------------
x_fast_smooth = np.linspace(tmin, tlim, 300)
y_fast_smooth = expo(x_fast_smooth, A_fast, tau_fast)

x_slow_smooth = np.linspace(tlim, tmax, 300)
y_slow_smooth = expo_slow(x_slow_smooth, A_slow, tau_slow)

# -----------------------
# Plot
# -----------------------
plt.figure()

plt.step(edges[:-1], sub_counts, where='post',
         color='green', linewidth=2,
         label='signal - bkg')

plt.plot(x_fast_smooth, y_fast_smooth,
         color='blue', linestyle='--', linewidth=2,
         label=fr'Fast fit ({tmin}-{tlim} ns): $\tau = {tau_fast:.1f} \pm {tau_fast_err:.1f}$ ns')

plt.plot(x_slow_smooth, y_slow_smooth,
         color='red', linestyle='--', linewidth=2,
         label=fr'Slow fit ({tlim}-{tmax} ns): $\tau = {tau_slow:.1f} \pm {tau_slow_err:.1f}$ ns')

plt.xlabel('Hit time since first hit [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt hit-time distribution')
plt.xlim(0, tmax)
plt.ylim(0, 10000)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# -----------------------
# Print results
# -----------------------
print(f"Split time tlim = {tlim} ns\n")

print("Fast component:")
print(f"  A   = {A_fast:.3f} ± {A_fast_err:.3f}")
print(f"  tau = {tau_fast:.3f} ± {tau_fast_err:.3f} ns")

print("Slow component:")
print(f"  A   = {A_slow:.3f} ± {A_slow_err:.3f}")
print(f"  tau = {tau_slow:.3f} ± {tau_slow_err:.3f} ns")
# Out:
# Split time tlim = 450 ns
#
# Fast component:
#   A   = 7808.274 ± 203.602
#   tau = 393.948 ± 20.572 ns
# Slow component:
#   A   = 2638.932 ± 52.903
#   tau = 752.373 ± 43.938 ns

# %%
def expo_const(t, A, tau, C):
    return A * np.exp(-t / tau) + C

bin_centers = 0.5 * (edges[:-1] + edges[1:])

# -----------------------
# Fit range
# -----------------------
tmin = 20
tmax = 1000

fit_mask = (bin_centers >= tmin) & (bin_centers <= tmax) & (sub_counts > 0)

x_fit = bin_centers[fit_mask]
y_fit = sub_counts[fit_mask]

# -----------------------
# Initial values and bounds
# -----------------------
A0 = max(float(np.nanmax(y_fit)), 1.0)
tau0 = 300.0
C0 = min(max(float(np.nanmin(y_fit)), 0.0), 1000.0)

p0 = [A0, tau0, C0]
bounds = ([0.0, 280.0, 0.0], [np.inf, 380.0, 1000.0])

print("p0 =", p0)

# -----------------------
# Fit
# -----------------------
popt, pcov = curve_fit(expo_const, x_fit, y_fit, p0=p0, bounds=bounds)

A_fit, tau_fit, C_fit = popt
A_err, tau_err, C_err = np.sqrt(np.diag(pcov))

# -----------------------
# Chi2 / ndf
# -----------------------
y_model = expo_const(x_fit, A_fit, tau_fit, C_fit)

sigma = np.sqrt(y_fit)
sigma[sigma <= 0] = 1.0

chi2 = np.sum(((y_fit - y_model) / sigma) ** 2)
ndf = len(y_fit) - len(popt)
chi2_ndf = chi2 / ndf if ndf > 0 else np.nan

# -----------------------
# Smooth curve for plotting
# -----------------------
x_smooth = np.linspace(0, tmax, 500)
y_smooth = expo_const(x_smooth, A_fit, tau_fit, C_fit)

# -----------------------
# Plot
# -----------------------
plt.figure()

plt.step(edges[:-1], sub_counts, where='post',
         color='green', linewidth=2,
         label='signal - bkg')

plt.plot(
    x_smooth, y_smooth,
    color='black', linestyle='--', linewidth=2,
    label=fr'Fit: $A e^{{-t/\tau}} + C$, $\tau = {tau_fit:.1f} \pm {tau_err:.1f}$ ns'
          '\n'
          fr'$C = {C_fit:.1f} \pm {C_err:.1f}$, $\chi^2/\mathrm{{ndf}} = {chi2_ndf:.2f}$'
)

plt.xlabel('Hit time since first hit [ns]')
plt.ylabel('events (a.u.)')
plt.title('Prompt hit-time distribution')
plt.xlim(0, tmax)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

print("Single exponential + constant fit:")
print(f"  A        = {A_fit:.3f} ± {A_err:.3f}")
print(f"  tau      = {tau_fit:.3f} ± {tau_err:.3f} ns")
print(f"  C        = {C_fit:.3f} ± {C_err:.3f}")
print(f"  chi2/ndf = {chi2_ndf:.3f}")
# Out:
# p0 = [7069.0, 300.0, 1000.0]
# Single exponential + constant fit:
#   A        = 6807.424 ± 154.928
#   tau      = 326.141 ± 23.066 ns
#   C        = 1000.000 ± 139.440
#   chi2/ndf = 18.869

# %%
def parse_times(times):
    # missing values
    if times is None or (isinstance(times, float) and np.isnan(times)):
        return np.array([])

    # already a list/array
    if isinstance(times, (list, tuple, np.ndarray)):
        arr = np.asarray(times, dtype=float)
        return arr[np.isfinite(arr)]

    # string representation of a list
    if isinstance(times, str):
        times = times.strip()
        if times == "":
            return np.array([])
        try:
            parsed = ast.literal_eval(times)
            arr = np.asarray(parsed, dtype=float)
            return arr[np.isfinite(arr)]
        except Exception:
            return np.array([])

    # scalar numeric
    if np.isscalar(times):
        try:
            arr = np.array([float(times)])
            return arr[np.isfinite(arr)]
        except Exception:
            return np.array([])

    return np.array([])

def shifted_event_times(times, tmax=1000):
    arr = parse_times(times)

    if arr.size == 0:
        return np.array([])

    t0 = np.min(arr)
    shifted = arr - t0
    return shifted[(shifted >= 0) & (shifted <= tmax)]

def event_time_features(times, tmax=1000, early_thr=100):
    t = shifted_event_times(times, tmax=tmax)

    if t.size == 0:
        return np.nan, np.nan, np.nan, np.nan

    t10 = np.percentile(t, 10)
    t50 = np.percentile(t, 50)
    fearly = np.mean(t < early_thr)
    trms = np.std(t)

    return t10, t50, fearly, trms

features = df_gamma["prompt_times_raw"].apply(
    lambda x: event_time_features(x, tmax=1000, early_thr=100)
)

df_gamma["t10"] = features.apply(lambda x: x[0])
df_gamma["t50"] = features.apply(lambda x: x[1])
df_gamma["fearly_100"] = features.apply(lambda x: x[2])
df_gamma["trms_check"] = features.apply(lambda x: x[3])

plot_df = df_gamma[np.isfinite(df_gamma["fearly_100"]) & np.isfinite(df_gamma["prompt_trms"])]

plt.figure()
plt.hist2d(plot_df["fearly_100"].values,
           plot_df["prompt_trms"].values,
           bins=20,
           cmin=0.0001)

plt.colorbar(label='Density')
plt.xlabel('Fraction of hits with t < 100 ns')
plt.ylabel('tRMS [ns]')
plt.title(f'{sig_run}')
plt.tight_layout()
plt.show()

features_bkg = df_gamma_bkg["prompt_times_raw"].apply(
    lambda x: event_time_features(x, tmax=1000, early_thr=100)
)

df_gamma_bkg["t10"] = features_bkg.apply(lambda x: x[0])
df_gamma_bkg["t50"] = features_bkg.apply(lambda x: x[1])
df_gamma_bkg["fearly_100"] = features_bkg.apply(lambda x: x[2])
df_gamma_bkg["trms_check"] = features_bkg.apply(lambda x: x[3])

plot_df_bkg = df_gamma_bkg[
    np.isfinite(df_gamma_bkg["fearly_100"]) & np.isfinite(df_gamma_bkg["prompt_trms"])
]

plt.figure()
plt.hist2d(plot_df_bkg["fearly_100"].values,
           plot_df_bkg["prompt_trms"].values,
           bins=20,
           cmin=0.0001)

plt.colorbar(label='Density')
plt.xlabel('Fraction of hits with t < 100 ns')
plt.ylabel('tRMS [ns]')
plt.title(f'{bkg_run}')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import ast
import matplotlib.pyplot as plt

def parse_times(times):
    # missing values
    if times is None or (isinstance(times, float) and np.isnan(times)):
        return np.array([])

    # already a list/array
    if isinstance(times, (list, tuple, np.ndarray)):
        arr = np.asarray(times, dtype=float)
        return arr[np.isfinite(arr)]

    # string representation of a list
    if isinstance(times, str):
        times = times.strip()
        if times == "":
            return np.array([])
        try:
            parsed = ast.literal_eval(times)
            arr = np.asarray(parsed, dtype=float)
            return arr[np.isfinite(arr)]
        except Exception:
            return np.array([])

    # scalar numeric
    if np.isscalar(times):
        try:
            arr = np.array([float(times)])
            return arr[np.isfinite(arr)]
        except Exception:
            return np.array([])

    return np.array([])

def shifted_event_times(times, tmax=1000):
    arr = parse_times(times)

    if arr.size == 0:
        return np.array([])

    t0 = np.min(arr)
    shifted = arr - t0
    return shifted[(shifted >= 0) & (shifted <= tmax)]

def event_time_features(times, tmax=1000, early_thr=100):
    t = shifted_event_times(times, tmax=tmax)

    if t.size == 0:
        return np.nan, np.nan, np.nan, np.nan

    t10 = np.percentile(t, 10)
    t50 = np.percentile(t, 50)
    fearly = np.mean(t < early_thr)
    trms = np.std(t)

    return t10, t50, fearly, trms

# -----------------------
# Signal
# -----------------------
features = df_gamma["prompt_times_raw"].apply(
    lambda x: event_time_features(x, tmax=1000, early_thr=100)
)

df_gamma["t10"] = features.apply(lambda x: x[0])
df_gamma["t50"] = features.apply(lambda x: x[1])
df_gamma["fearly_100"] = features.apply(lambda x: x[2])
df_gamma["trms_check"] = features.apply(lambda x: x[3])

plot_df = df_gamma[
    np.isfinite(df_gamma["fearly_100"]) & np.isfinite(df_gamma["prompt_nhits"])
]

plt.figure()
plt.hist2d(plot_df["fearly_100"].values,
           plot_df["prompt_nhits"].values,
           bins=50,
           cmin=0.0001)

plt.colorbar(label='Density')
plt.xlabel('Fraction of hits with t < 100 ns')
plt.ylabel('nHits')
plt.title(f'{sig_run}')
plt.tight_layout()
plt.show()

# -----------------------
# Background
# -----------------------
features_bkg = df_gamma_bkg["prompt_times_raw"].apply(
    lambda x: event_time_features(x, tmax=1000, early_thr=100)
)

df_gamma_bkg["t10"] = features_bkg.apply(lambda x: x[0])
df_gamma_bkg["t50"] = features_bkg.apply(lambda x: x[1])
df_gamma_bkg["fearly_100"] = features_bkg.apply(lambda x: x[2])
df_gamma_bkg["trms_check"] = features_bkg.apply(lambda x: x[3])

plot_df_bkg = df_gamma_bkg[
    np.isfinite(df_gamma_bkg["fearly_100"]) & np.isfinite(df_gamma_bkg["prompt_nhits"])
]

plt.figure()
plt.hist2d(plot_df_bkg["fearly_100"].values,
           plot_df_bkg["prompt_nhits"].values,
           bins=50,
           cmin=0.0001)

plt.colorbar(label='Density')
plt.xlabel('Fraction of hits with t < 100 ns')
plt.ylabel('nHits')
plt.title(f'{bkg_run}')
plt.tight_layout()
plt.show()

# %%
plt.hist2d(df.prompt_nhits.values, df.prompt_trms.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.xlabel('nHits')
plt.ylabel('tRMS [ns]')
plt.title(f'{sig_run}')
plt.show()

plt.hist2d(df_bkg.prompt_nhits.values, df_bkg.prompt_trms.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.xlabel('nHits')
plt.ylabel('tRMS [ns]')
plt.title(f'{bkg_run}')
plt.show()

# %%
# -------------------------
# "prompt" (green solid)
# -------------------------
prompt_nhits = df_gamma.prompt_trms.values
prompt_nhits_bkg = df_gamma_bkg.prompt_trms.values

hist_p_bkg, bins_edges = np.histogram(
    prompt_nhits_bkg, bins=25, range=(prompt_t_rms_min, prompt_t_rms_max)
)
hist_p_sig, _ = np.histogram(prompt_nhits, bins=bins_edges)

# scaled difference: sig*(Nbkg/Nsig) - bkg
diff_prompt = hist_p_sig * (N_events_bkg / N_events_sig) - hist_p_bkg

# -------------------------
# "candidate" (green dashed)
# -------------------------
prompt_nhits = df.prompt_trms.unique()
prompt_nhits_bkg = df_bkg.prompt_trms.unique()

hist_c_bkg, _ = np.histogram(
    prompt_nhits_bkg, bins=25, range=(prompt_t_rms_min, prompt_t_rms_max)
)
hist_c_sig, _ = np.histogram(prompt_nhits, bins=bins_edges)

diff_cand = hist_c_sig * (N_events_bkg / N_events_sig) - hist_c_bkg

# -------------------------
# Ratio panel: cand / prompt (in %), + red 60% line
# -------------------------
ratio = np.divide(
    diff_cand.astype(float),
    diff_prompt.astype(float),
    out=np.full_like(diff_cand, np.nan, dtype=float),
    where=(diff_prompt != 0)
) * 100.0

# Optional errors (approx): treat each diff as independent with variance ~ (k^2 * sig + bkg)
# where k = N_events_bkg/N_events_sig and sig,bkg are Poisson.
k = (N_events_bkg / N_events_sig)
var_prompt = (k**2) * hist_p_sig.astype(float) + hist_p_bkg.astype(float)
var_cand   = (k**2) * hist_c_sig.astype(float) + hist_c_bkg.astype(float)
sigma_prompt = np.sqrt(var_prompt)
sigma_cand   = np.sqrt(var_cand)

ratio_err = np.full_like(ratio, np.nan, dtype=float)
mask = (diff_prompt != 0) & np.isfinite(diff_prompt) & np.isfinite(diff_cand)
ratio_err[mask] = np.abs(ratio[mask]) * np.sqrt(
    (sigma_cand[mask] / np.where(diff_cand[mask] != 0, np.abs(diff_cand[mask]), np.nan))**2 +
    (sigma_prompt[mask] / np.abs(diff_prompt[mask]))**2
)

# x for step plots
x = bins_edges[:-1]
centers = 0.5 * (bins_edges[:-1] + bins_edges[1:])

# -------------------------
# Plot
# -------------------------
fig, (ax, rax) = plt.subplots(
    2, 1, sharex=True,
    gridspec_kw={"height_ratios": [3, 1], "hspace": 0.05},
    figsize=(7, 6)
)

# top: scaled differences
ax.step(x, diff_prompt, where="post", linewidth=2, color="green", label="prompt")
ax.step(x, diff_cand,   where="post", linewidth=2, color="green", linestyle="--", label="candidate")
ax.set_ylabel("events (a.u.)")
ax.set_title("Prompt signal candidates")
ax.legend()
ax.grid(alpha=0.3)

# bottom: ratio cand/prompt (%)
#rax.axhline(100.0, color="black", lw=1, alpha=0.7)          # 100%: cand == prompt
#rax.axhline(75.0,  color="red",   lw=2, alpha=0.9, ls="--") # 60% reference
rax.step(x, ratio, where="post", color="green", lw=2)

# optional: ratio error bars (can be noisy when diffs ~ 0)
rax.errorbar(centers, ratio, yerr=ratio_err, fmt="none", ecolor="green", elinewidth=1, alpha=0.6)

rax.set_xlabel("tRMS [ns]")
rax.set_ylabel("ratio (%)")
rax.set_ylim(0, 100)
rax.grid(alpha=0.3)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

cols = ["delayed_x", "delayed_y", "delayed_z"]
labels = ["X [cm]", "Y [cm]", "Z [cm]"]
source_pos = {"prompt_x": pos[0], "prompt_y": pos[1], "prompt_z": pos[2]}

alpha = N_events_bkg / N_events_sig   # scale signal to background exposure

# Clean arrays
def clean(arr):
    arr = np.asarray(arr)
    return arr[np.isfinite(arr)]

sx, sy, sz = [clean(df[c].to_numpy()) for c in cols]
bx, by, bz = [clean(df_bkg[c].to_numpy()) for c in cols]

n_bins = 30

global_min = 0 
global_max = 20

# Shared bin ranges for consistency
xmin, xmax = -2000, 2000
ymin, ymax = -2000+424.725, 2000+424.725
zmin, zmax = -2000, 2000
xbins = np.linspace(xmin, xmax, n_bins+1)
ybins = np.linspace(ymin, ymax, n_bins+1)
zbins = np.linspace(zmin, zmax, n_bins+1)

fig, axes = plt.subplots(2, 2, figsize=(12, 10), constrained_layout=True)

# --------------------------
# Shape parameters
# --------------------------
# Rectangle for XY
rect_xmin, rect_xmax = -1500, 1500
rect_ymin, rect_ymax = -1500+424.725, 1500+424.725

# Circle for XZ
circle_center = (0, 0)   # (x, z)
circle_radius = 1500

shape_style = dict(
    fill=False,
    edgecolor="white",
    linestyle=":",
    linewidth=2.5
)

# SIGNAL: X vs Y
h_sig_xy, xedges, yedges, img_sig_xy = axes[0,0].hist2d(
    sx, sy, bins=[xbins, ybins], weights=np.full(sx.shape, alpha),
    cmap='plasma', vmin=global_min, vmax=global_max
)
axes[0,0].plot(source_pos["prompt_x"], source_pos["prompt_y"], 'gx', ms=8, mew=4, label='Source position')
axes[0,0].set_xlabel(labels[0]); axes[0,0].set_ylabel(labels[1])
axes[0,0].set_title("Signal")
axes[0,0].legend()
fig.colorbar(img_sig_xy, ax=axes[0,0], label="Events (a.u.)")

# Add rectangle on XY
rect_xy = patches.Rectangle(
    (rect_xmin, rect_ymin),
    rect_xmax - rect_xmin,
    rect_ymax - rect_ymin,
    **shape_style
)
axes[0,0].add_patch(rect_xy)

# SIGNAL: X vs Z
h_sig_xz, xedges, zedges, img_sig_xz = axes[0,1].hist2d(
    sx, sz, bins=[xbins, zbins], weights=np.full(sx.shape, alpha),
    cmap='plasma', vmin=global_min, vmax=global_max
)
axes[0,1].plot(source_pos["prompt_x"], source_pos["prompt_z"], 'gx', ms=8, mew=4, label='Source position')
axes[0,1].set_xlabel(labels[0]); axes[0,1].set_ylabel(labels[2])
axes[0,1].set_title("Signal")
fig.colorbar(img_sig_xz, ax=axes[0,1], label="Events (a.u.)")

# Add circle on XZ
circle_xz = patches.Circle(
    circle_center, circle_radius, **shape_style
)
axes[0,1].add_patch(circle_xz)

# BACKGROUND: X vs Y
h_bkg_xy, xedges, yedges, img_bkg_xy = axes[1,0].hist2d(
    bx, by, bins=[xbins, ybins],
    cmap='plasma', vmin=global_min, vmax=global_max
)
axes[1,0].plot(source_pos["prompt_x"], source_pos["prompt_y"], 'gx', ms=8, mew=4, label='Source position')
axes[1,0].set_xlabel(labels[0]); axes[1,0].set_ylabel(labels[1])
axes[1,0].set_title("Background")
fig.colorbar(img_bkg_xy, ax=axes[1,0], label="Events (a.u.)")

# Add rectangle on XY
rect_bkg_xy = patches.Rectangle(
    (rect_xmin, rect_ymin),
    rect_xmax - rect_xmin,
    rect_ymax - rect_ymin,
    **shape_style
)
axes[1,0].add_patch(rect_bkg_xy)

# BACKGROUND: X vs Z
h_bkg_xz, xedges, zedges, img_bkg_xz = axes[1,1].hist2d(
    bx, bz, bins=[xbins, zbins],
    cmap='plasma', vmin=global_min, vmax=global_max
)
axes[1,1].plot(source_pos["prompt_x"], source_pos["prompt_z"], 'gx', ms=8, mew=4, label='Source position')
axes[1,1].set_xlabel(labels[0]); axes[1,1].set_ylabel(labels[2])
axes[1,1].set_title("Background")
fig.colorbar(img_bkg_xz, ax=axes[1,1], label="Events (a.u.)")

# Add circle on XZ
circle_bkg_xz = patches.Circle(
    circle_center, circle_radius, **shape_style
)
axes[1,1].add_patch(circle_bkg_xz)

fig.suptitle(f"AmBe Run {sig_run} - Delayed Candidates")
plt.show()

# %%
cols = ["delayed_x", "delayed_y", "delayed_z"]
labels = ["X [cm]", "Y [cm]", "Z [cm]"]

source_pos = {"delayed_x": pos[0], "delayed_y": pos[1], "delayed_z": pos[2]}

alpha = N_events_bkg / N_events_sig  # scale signal to background exposure

fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharey=True, constrained_layout=True)

for ax, col, label in zip(axes, cols, labels):
    # Drop non-finite
    s = df[col].to_numpy()
    b = df_bkg[col].to_numpy()
    s = s[np.isfinite(s)]
    b = b[np.isfinite(b)]

    # Common bins from combined range
    xmin = np.min([s.min(), b.min()]) if len(s) and len(b) else (s.min() if len(s) else b.min())
    xmax = np.max([s.max(), b.max()]) if len(s) and len(b) else (s.max() if len(s) else b.max())
    bins = np.linspace(xmin, xmax, 20)  # 50 bins

    # Histograms: scale signal counts by alpha via weights
    ax.hist(s, bins=bins, weights=np.full(s.shape, alpha), color="blue", alpha=0.6, label=f'signal')
    ax.hist(b, bins=bins, color="red", alpha=0.6, label=f'background')

    # Source marker line
    vline = source_pos[col]
    ax.axvline(vline, color="k", linestyle="--", linewidth=1.5, label="Source position")

    ax.set_xlabel(label)
    ax.grid(alpha=0.3)
    if(col =='delayed_x'):
        ax.legend()

axes[0].set_ylabel("Events (a.u.)")
fig.suptitle(f"AmBe Run {sig_run} - Delayed Candidates")
plt.show()

# %%
cols = ["delayed_x", "delayed_y", "delayed_z"]
labels = ["X [cm]", "Y [cm]", "Z [cm]"]

source_pos = {"delayed_x": pos[0], "delayed_y": pos[1], "delayed_z": pos[2]}
alpha = N_events_bkg / N_events_sig  # scale signal to background exposure

fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharey=True, constrained_layout=True)

for ax, col, label in zip(axes, cols, labels):
    s = df[col].to_numpy()
    b = df_bkg[col].to_numpy()
    s = s[np.isfinite(s)]
    b = b[np.isfinite(b)]

    # Common bins from combined range
    xmin = np.min([s.min(), b.min()]) if len(s) and len(b) else (s.min() if len(s) else b.min())
    xmax = np.max([s.max(), b.max()]) if len(s) and len(b) else (s.max() if len(s) else b.max())
    bins = np.linspace(xmin, xmax, 20)

    # Bin counts and subtraction: (scaled signal) - background
    s_counts, _ = np.histogram(s, bins=bins)
    b_counts, _ = np.histogram(b, bins=bins)
    diff = alpha * s_counts - b_counts
    
    # (optional) Poisson uncertainty band: Var = alpha^2*S + B
    diff_sigma = np.sqrt((alpha**2) * s_counts + b_counts)

    # Peak bin of the plotted histogram
    imax = np.argmax(diff)
    mode_bin_center = 0.5 * (bins[imax] + bins[imax + 1])
    print(f"Peak bin of {col}: {mode_bin_center:.2f}, true value {source_pos[col]}")


    # Plot only the subtraction
    ax.step(bins[:-1], diff, where="post", color="k", linewidth=2, label="candidates")
    ax.fill_between(
        bins[:-1], diff - diff_sigma, diff + diff_sigma,
        step="post", color="k", alpha=0.15, linewidth=0
    )
    ax.axhline(0, color="k", linewidth=1, alpha=0.4)

    # Source marker line
    ax.axvline(source_pos[col], color="k", linestyle="--", linewidth=1.5, label="Source position")

    ax.set_xlabel(label)
    ax.grid(alpha=0.3)
    if col == "delayed_x":
        ax.legend()

axes[0].set_ylabel("Events (scaled subtraction)")
fig.suptitle(f"AmBe Run {sig_run} - Delayed Candidates (Subtracted)")
plt.show()
# Out:
# Peak bin of delayed_x: -554.56, true value -476.4
# Peak bin of delayed_y: 658.01, true value 729.725
# Peak bin of delayed_z: -583.37, true value 291.7

# %%
prompt_nhits = df.vertex_chi2.values
prompt_nhits_bkg = df_bkg.vertex_chi2.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=100, range=(0,50))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
#plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('chi2/ndf')
plt.ylabel('events (a.u.)')
plt.title('Delayed signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
reco_pos = [float(df['delayed_x'].mean()), 
          float(df['delayed_y'].mean()), 
          float(df['delayed_z'].mean())]
reco_offset = [reco_pos[0] - pos[0], 
          reco_pos[1] - pos[1], 
          reco_pos[2] - pos[2]]
reco_pos_err = [float(df['delayed_x'].std() / np.sqrt(len(df))),
                float(df['delayed_y'].std() / np.sqrt(len(df))),
                float(df['delayed_z'].std() / np.sqrt(len(df)))]

reco_pos, reco_offset, reco_pos_err
# Out:
# ([-228.07426506910943, 252.1651590335473, -66.46494748647079],
#  [248.32573493089055, -477.5598409664527, -358.1649474864708],
#  [14.847578272089116, 15.853191935320826, 16.754191723952058])

# %%
reco_pos_err = [float(df['delayed_x'].std() / np.sqrt(len(df))),
                float(df['delayed_y'].std() / np.sqrt(len(df))),
                float(df['delayed_z'].std() / np.sqrt(len(df)))]
reco_pos_err
# Out:
# [14.847578272089116, 15.853191935320826, 16.754191723952058]

# %%
if sig_run == '2385':
    # Create weighted values for signal
    all_values = []
    all_weights = []

    for idx, row in df.iterrows():
        pmt_values = row['prompt_mpmt']
        nhits = row['prompt_nhits']
        
        # Add the PMT values
        all_values.extend(pmt_values)
        
        # Weight each PMT entry by 1/nhits for this event
        weights = [1.0 / nhits] * len(pmt_values)
        all_weights.extend(weights)

    all_values = np.array(all_values)
    all_weights = np.array(all_weights)

    # Create weighted values for background
    all_values_bkg = []
    all_weights_bkg = []

    for idx, row in df_bkg.iterrows():
        pmt_values_bkg = row['prompt_mpmt']
        nhits_bkg = row['prompt_nhits']
        
        # Add the PMT values
        all_values_bkg.extend(pmt_values_bkg)
        
        # Weight each PMT entry by 1/nhits for this event
        weights_bkg = [1.0 / nhits_bkg] * len(pmt_values_bkg)
        all_weights_bkg.extend(weights_bkg)

    all_values_bkg = np.array(all_values_bkg)
    all_weights_bkg = np.array(all_weights_bkg)

    # Scale signal weights by N_events_bkg / N_events_sig
    all_weights_scaled = all_weights * (N_events_bkg / N_events_sig)

    plt.figure(figsize=(10, 6))
    plt.hist(all_values, bins=105, weights=all_weights_scaled, color="blue", alpha=0.6, label=f'signal - run {sig_run}')
    plt.hist(all_values_bkg, bins=105, weights=all_weights_bkg, color="red", alpha=0.6, label=f'background - run {bkg_run}')
    plt.xlabel('mPMT ID')
    plt.ylabel('Frequency per nhits per event (a.u.)')
    plt.title('Hits per PMT for Prompt Signal')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()

# %%
if sig_run == '2385':
    import matplotlib.pyplot as plt
    import numpy as np

    # Create weighted values for signal
    all_values = []
    all_weights = []

    for idx, row in df.iterrows():
        pmt_values = row['prompt_mpmt']
        nhits = row['prompt_nhits']
        
        # Add the PMT values
        all_values.extend(pmt_values)
        
        # Weight each PMT entry by 1/nhits for this event
        weights = [1.0 / nhits] * len(pmt_values)
        all_weights.extend(weights)

    all_values = np.array(all_values)
    all_weights = np.array(all_weights)

    # Create weighted values for background
    all_values_bkg = []
    all_weights_bkg = []

    for idx, row in df_bkg.iterrows():
        pmt_values_bkg = row['prompt_mpmt']
        nhits_bkg = row['prompt_nhits']
        
        # Add the PMT values
        all_values_bkg.extend(pmt_values_bkg)
        
        # Weight each PMT entry by 1/nhits for this event
        weights_bkg = [1.0 / nhits_bkg] * len(pmt_values_bkg)
        all_weights_bkg.extend(weights_bkg)

    all_values_bkg = np.array(all_values_bkg)
    all_weights_bkg = np.array(all_weights_bkg)

    # Scale signal weights by N_events_bkg / N_events_sig
    all_weights_scaled = all_weights * (N_events_bkg / N_events_sig)

    plt.figure(figsize=(12, 6))

    # Add shaded regions for detector parts
    plt.axvspan(0, 20, alpha=0.15, color='gray')#, label='Bottom')
    plt.axvspan(21, 84, alpha=0.15, color='yellow')#, label='Barrel')
    plt.axvspan(85, 105, alpha=0.15, color='lightblue')#, label='Top')

    # Plot histograms
    plt.hist(all_values, bins=105, weights=all_weights_scaled, color="blue", alpha=0.6, label=f'signal - run {sig_run}')
    plt.hist(all_values_bkg, bins=105, weights=all_weights_bkg, color="red", alpha=0.6, label=f'background - run {bkg_run}')

    plt.xlabel('mPMT ID')
    plt.ylabel('Frequency per nhits per event (a.u.)')
    plt.title('Hits per PMT for Prompt Signal')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.xlim(0, 105)
    plt.show()

# %%
if sig_run == '2385':
    # Define bins
    bins = np.linspace(0, 105, 106)  # 105 bins from 0 to 105

    # Create histograms for signal and background
    hist_sig, bin_edges = np.histogram(all_values, bins=bins, weights=all_weights_scaled)
    hist_bkg, _ = np.histogram(all_values_bkg, bins=bins, weights=all_weights_bkg)

    # Bin-by-bin subtraction
    hist_subtraction = hist_sig - hist_bkg

    # Plot the subtraction
    plt.figure(figsize=(12, 6))

    # Add shaded regions for detector parts
    plt.axvspan(0, 20, alpha=0.15, color='gray')#, label='Bottom')
    plt.axvspan(21, 84, alpha=0.15, color='yellow')#, label='Barrel')
    plt.axvspan(85, 105, alpha=0.15, color='lightblue')#, label='Top')

    # Add horizontal line at y=0 for reference
    plt.axhline(y=0, color='black', linestyle='--', linewidth=1, alpha=0.5)

    # Plot subtraction histogram
    plt.step(bin_edges[:-1], hist_subtraction, where='post', color='green', lw=2, label='Signal - Background')

    plt.xlabel('mPMT ID')
    plt.ylabel('Frequency difference (a.u.)')
    plt.title('Signal - Background per PMT (Prompt)')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.xlim(0, 105)
    plt.show()

# %%
prompt_nhits = df.delayed_nhits.values
prompt_nhits_bkg = df_bkg.delayed_nhits.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=20, range=(delayed_nhits_min, delayed_nhits_max))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2)
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('nHits')
plt.ylabel('events (a.u.)')
plt.title('Delayed signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
prompt_nhits = df.delayed_trms_tof.values
prompt_nhits_bkg = df_bkg.delayed_trms_tof.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=30)
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('tRMS [ns]')
plt.ylabel('events (a.u.)')
plt.title('Delayed signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
prompt_nhits = df.DeltaR.values
prompt_nhits_bkg = df_bkg.DeltaR.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=20)
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('deltaR [mm]')
plt.ylabel('events (a.u.)')
plt.title('Delayed signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
plt.hist2d(df.delayed_trms_tof.values, df.DeltaR.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.ylabel('tRMS [ns]')
plt.xlabel('nHits')
plt.title(f'{sig_run}')
plt.show()

# %%
plt.hist2d(df.delayed_nhits.values, df.DeltaR.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.ylabel('deltaR [cm]')
plt.xlabel('nHits')
plt.title(f'{sig_run}')
plt.show()

# %%
plt.hist2d(df.delayed_trms_tof.values, df.DeltaR.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.ylabel('tRMS [ns]')
plt.xlabel('nHits')
plt.title(f'{sig_run}')
plt.show()

# %%
plt.hist2d(df.delayed_trms_tof.values, df.DeltaT.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.ylabel('tcapt [mus]')
plt.xlabel('tRMS [ns]')
plt.title(f'{sig_run}')
plt.show()

# %%
plt.hist2d(df_bkg.delayed_trms_tof.values, df_bkg.DeltaT.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.ylabel('tcapt [mus]')
plt.xlabel('tRMS [ns]')
plt.title(f'{bkg_run}')
plt.show()

# %%
plt.hist2d(df_bkg.delayed_nhits.values, df_bkg.DeltaT.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
#plt.xlim(0, 270000)  # Set x-axis limits
#plt.ylim(0, 150)
plt.ylabel('tcapt [mus]')
plt.xlabel('nHits')
plt.title(f'{sig_run}')
plt.show()

# %%
df
# Out:
#       event_number  prompt_nhits    prompt_time  prompt_trms  prompt_tmean  \
# 0              225            79   94752.038904   240.989905    267.943348
# 1             1152            55  143737.838639   283.062143    367.640804
# 2             1428            51   39982.762887   226.832358    288.158803
# 3             1513            65  157963.311728   252.818901    281.873041
# 4             1575            58   58816.738314   211.926283    245.578489
# ...            ...           ...            ...          ...           ...
# 1686        100140            55  145792.507520   270.922199    352.480612
# 1687        100142            58   10073.469699   227.427710    214.114086
# 1688        101604            72  223379.965150   264.262939    277.783338
# 1689        101804            59   33288.301149   233.455031    287.125359
# 1690        101923           192   26498.768944   240.016801    283.065166
#
# ...

# %%
prompt_nhits = df.DeltaT.values
prompt_nhits_bkg = df_bkg.DeltaT.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(0, 150))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2)
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.xlabel(r'$\Delta t$ ($\mu$s)')
plt.ylabel('events (a.u.)')
plt.title(f'Delayed signal candidates - Run {sig_run}')
plt.legend()
plt.grid(alpha=0.3)

plt.figure()
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel(r'$\Delta t$ ($\mu$s)')
plt.ylabel('Number of signal candidates')
plt.grid(alpha=0.3)
plt.legend()
plt.show()

bin_centers = 0.5 * (bins_edges[:-1] + bins_edges[1:])
values = hist_sig * N_events_bkg / N_events_sig - hist


# histogram pieces you already have


hist_deltar, _ = np.histogram(df.DeltaR.values, bins=100, range=(0, 1500))
hist_deltar_bkg, bins_edges = np.histogram(df_bkg.DeltaR.values, bins=100, range=(0, 1500))
hist_deltar = hist_deltar * N_events_bkg / N_events_sig - hist_deltar_bkg
bin_centers_deltar = 0.5 * (bins_edges[:-1] + bins_edges[1:])

hist_prompt_nhits, _ = np.histogram(df.prompt_nhits.values, bins=30, range=(30, 300))
hist_prompt_nhits_bkg, bins_edges = np.histogram(df_bkg.prompt_nhits.values, bins=30, range=(30, 300))
hist_prompt_nhits = hist_prompt_nhits * N_events_bkg / N_events_sig - hist_prompt_nhits_bkg
bin_centers_prompt_nhits = 0.5 * (bins_edges[:-1] + bins_edges[1:])

hist_delayed_nhits, _ = np.histogram(df.delayed_nhits.values, bins=20, range=(10, 50))
hist_delayed_nhits_bkg, bins_edges = np.histogram(df_bkg.delayed_nhits.values, bins=20, range=(10, 50))
hist_delayed_nhits = hist_delayed_nhits * N_events_bkg / N_events_sig - hist_delayed_nhits_bkg
bin_centers_delayed_nhits = 0.5 * (bins_edges[:-1] + bins_edges[1:])

hist_prompt_trms, _ = np.histogram(df.prompt_trms.values, bins=30, range=(200, 500))
hist_prompt_trms_bkg, bins_edges = np.histogram(df_bkg.prompt_trms.values, bins=30, range=(200, 500))
hist_prompt_trms = hist_prompt_trms * N_events_bkg / N_events_sig - hist_prompt_trms_bkg
bin_centers_prompt_trms = 0.5 * (bins_edges[:-1] + bins_edges[1:])

hist_delayed_trms, _ = np.histogram(df.delayed_trms_tof.values, bins=30, range=(0, 10))
hist_delayed_trms_bkg, bins_edges = np.histogram(df_bkg.delayed_trms_tof.values, bins=30, range=(0, 10))
hist_delayed_trms = hist_delayed_trms * N_events_bkg / N_events_sig - hist_delayed_trms_bkg
bin_centers_delayed_trms = 0.5 * (bins_edges[:-1] + bins_edges[1:])

hist_deltat, _ = np.histogram(df.DeltaT.values, bins=25, range=(0, 150))
hist_deltat_bkg, bins_edges = np.histogram(df_bkg.DeltaT.values, bins=25, range=(0, 150))
hist_deltat = hist_deltat * N_events_bkg / N_events_sig - hist_deltat_bkg
bin_centers_deltat = 0.5 * (bins_edges[:-1] + bins_edges[1:])


np.savez(
    f'/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{sig_run}_{title}.npz',
    deltat=hist_deltat,
    bins_deltat=bin_centers,
    deltaR=hist_deltar,
    bins_deltaR=bin_centers_deltar,
    prompt_nhits=hist_prompt_nhits,
    bins_prompt_nhits=bin_centers_prompt_nhits,
    delayed_nhits=hist_delayed_nhits,
    bins_delayed_nhits=bin_centers_delayed_nhits,
    prompt_trms=hist_prompt_trms,
    bins_prompt_trms=bin_centers_prompt_trms,
    delayed_trms=hist_delayed_trms,
    bins_delayed_trms=bin_centers_delayed_trms,
)


scale = N_events_bkg / N_events_sig
sig_scaled = hist_sig * scale
data = sig_scaled - hist

# Proper approx errors for (scale*sig - bkg)
errors = np.sqrt((scale**2) * hist_sig + hist)

xmin = 5.0  # microseconds

mask = (
    np.isfinite(errors) &
    (errors > 0) &
    (bin_centers > xmin)
    # optional:
    # & (data > 0)
)

# Fit only bins with finite errors and positive content (optional but helps)
#mask = np.isfinite(errors) & (errors > 0) & (data > 0)

x = bin_centers[mask]
y = data[mask]
s = errors[mask]

def exp_func(x, A, tau, B):
    return A*np.exp(-x/tau)+B

tau0 = np.mean(df.DeltaT.values)   # seed you want
A0   = np.max(data)                   # typical seed for amplitude
B0   = np.min(data)   

p0 = (A0, tau0, B0)

popt, pcov = curve_fit(exp_func, x, y, p0=p0)
A_fit, tau_fit, B_fit = popt
A_err, tau_err, B_err = np.sqrt(np.diag(pcov))

print(f"Seed used: A0={A0:.4g}, tau0={tau0:.4g}")
print(f"Ajuste: A = {A_fit:.2f} ± {A_err:.2f}, tau = {tau_fit:.2f} ± {tau_err:.2f}, B = {B_fit:.2f} ± {B_err:.2f}")


plt.figure()
plt.step(bins_edges[:-1], data, where='post', linewidth=2, label='Data', color='green')
plt.errorbar(bin_centers, data, yerr=errors, fmt='none', ecolor='black', elinewidth=1, capsize=2)
x_fit = np.linspace(xmin, bin_centers[mask].max(), 400)
plt.plot(x_fit, exp_func(x_fit, *popt), '-', color="black", label=f'Fit data: A·exp(-x/τ) + B, τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs')
#x_fit = np.arange(int(bin_centers[1]), int(bin_centers[-6]), 1)
#plt.plot(x_fit, exp_func(x_fit, *popt), 'r-', label=f'Fit data: A·exp(-x/τ), τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs', color="black")
plt.xlabel(r'Time ($\mu$s)')
plt.ylabel('Number of signal candidates')
plt.grid(alpha=0.3)
plt.title(f'Delayed signal candidates - Run {sig_run}')
plt.legend()
plt.tight_layout()
plt.ylim(bottom = 0)
plt.show()
# Out:
# Seed used: A0=173.2, tau0=61.22
# Ajuste: A = 175.02 ± 11.72, tau = 64.76 ± 15.68, B = 25.50 ± 15.10

# %%
# -----------------------------
# Inputs (adjust if needed)
# -----------------------------
xmin_fit = 5.0                   # match first script
plot_min, plot_max = 0.0, 150.0
xmax_scale = 150.0

data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{sig_run}_{title}.npz"
mc_path   = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_2386_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz"

# -----------------------------
# Load Data
# -----------------------------
ddata = np.load(data_path)
bin_centers_common = ddata["bins_deltat"].astype(float)
data_vals = ddata["deltat"].astype(float)

# Keep these only for plotting, not for fitting
errors = np.sqrt(np.abs(data_vals))
errors = np.maximum(errors, 1.0)

# -----------------------------
# Load MC
# -----------------------------
dmc = np.load(mc_path)
mc_x = dmc["bins_deltat"].astype(float)
mc_y_raw = dmc["deltat"].astype(float)

# Detect whether MC bins are edges or centers
if len(mc_x) == len(mc_y_raw) + 1:
    mc_centers = 0.5 * (mc_x[:-1] + mc_x[1:])
    mc_vals = mc_y_raw
else:
    mc_centers = mc_x
    mc_vals = mc_y_raw

# Interpolate MC onto Data grid if needed
same_grid = (mc_centers.shape == bin_centers_common.shape) and np.allclose(mc_centers, bin_centers_common)
if not same_grid:
    mc_on_data_grid = np.interp(bin_centers_common, mc_centers, mc_vals, left=0.0, right=0.0)
else:
    mc_on_data_grid = mc_vals

# -----------------------------
# Scale MC to match maxima
# -----------------------------
mask_scale = (
    (bin_centers_common >= xmin_fit) &
    (bin_centers_common <= xmax_scale) &
    np.isfinite(data_vals) & np.isfinite(mc_on_data_grid)
)

max_data = np.max(data_vals[mask_scale]) if np.any(mask_scale) else np.max(data_vals)
max_mc   = np.max(mc_on_data_grid[mask_scale]) if np.any(mask_scale) else np.max(mc_on_data_grid)

scale_factor = (max_data / max_mc) if max_mc > 0 else 1.0
mc_scaled = mc_on_data_grid * scale_factor

print("Data file:", data_path)
print("MC file:", mc_path)
print("Same binning grid?", same_grid)
print(f"Scale factor (match maxima in [{xmin_fit},{xmax_scale}] us): {scale_factor:.4g}")

# -----------------------------
# Ratio panel: (Data - MC) / Data
# -----------------------------
data = data_vals.astype(float)
mc   = mc_scaled.astype(float)
data_err = errors.astype(float)

ratio = np.full_like(data, np.nan, dtype=float)
ratio_err = np.full_like(data, np.nan, dtype=float)

mask_ratio = np.isfinite(data) & np.isfinite(mc) & (data != 0)
ratio[mask_ratio] = (data[mask_ratio] - mc[mask_ratio]) / data[mask_ratio]
ratio_err[mask_ratio] = data_err[mask_ratio] / np.abs(data[mask_ratio])

# -----------------------------
# Fit exponential: same style as first script
# -----------------------------
def exp_func(x, A, tau, B):
    return A * np.exp(-x / tau) + B

# Match first script mask logic as closely as possible
mask_fit = (
    (bin_centers_common > xmin_fit) &
    np.isfinite(data)
)

if np.sum(mask_fit) >= 4:
    x_fit_data = bin_centers_common[mask_fit]
    y_fit_data = data[mask_fit]

    # Same seed philosophy as first script
    tau0 = np.mean(x_fit_data)       # in first script this was np.mean(df.DeltaT.values)
    A0   = np.max(data)
    B0   = np.min(data)
    p0   = (A0, tau0, B0)

    # IMPORTANT: no sigma -> unweighted fit, like first script
    popt, pcov = curve_fit(
        exp_func,
        x_fit_data,
        y_fit_data,
        p0=p0,
        maxfev=20000
    )

    A_fit, tau_fit, B_fit = popt
    A_err, tau_err, B_err = np.sqrt(np.diag(pcov))

    print(f"Seed used: A0={A0:.4g}, tau0={tau0:.4g}")
    print(f"Fit Data: A = {A_fit:.2f} ± {A_err:.2f}, tau = {tau_fit:.2f} ± {tau_err:.2f} us, B = {B_fit:.2f} ± {B_err:.2f}")

    x_fit_plot = np.linspace(max(xmin_fit, plot_min), plot_max, 400)
else:
    popt = None
    x_fit_plot = None
    print("Fit skipped: not enough valid bins for A*exp(-x/tau)+B fit.")

# -----------------------------
# Optional chi2/ndf using plotting errors
# -----------------------------
def chi2_ndf(y_obs, y_err, y_exp, n_params):
    mask = np.isfinite(y_obs) & np.isfinite(y_err) & np.isfinite(y_exp) & (y_err > 0)
    n = int(np.sum(mask))
    if n <= n_params:
        return np.nan, n, n - n_params
    chi2 = np.sum(((y_obs[mask] - y_exp[mask]) / y_err[mask])**2)
    ndf = n - n_params
    return chi2 / ndf, n, ndf

if popt is not None:
    y_model_data = exp_func(x_fit_data, *popt)
    redchi2_data, npts_data, ndf_data = chi2_ndf(
        y_fit_data,
        data_err[mask_fit],
        y_model_data,
        n_params=3
    )
    print(f"Chi2/ndf Data = {redchi2_data:.2f}  (over {npts_data} pts, ndf={ndf_data})")
else:
    redchi2_data = np.nan

# -----------------------------
# Plot
# -----------------------------
fig, (ax_top, ax_bottom) = plt.subplots(
    2, 1, sharex=True,
    gridspec_kw={"height_ratios": [3, 1]},
    figsize=(10, 8)
)

# Top: Data + MC
ax_top.errorbar(
    bin_centers_common, data, yerr=data_err,
    fmt="o", color="C0",
    ecolor="C0", elinewidth=1.5, capsize=3, markersize=6,
    label="Data (signal - bkg)"
)

ax_top.step(
    bin_centers_common, mc, where="post",
    linewidth=2, color="red",
    label="MC (scaled)"
)

if popt is not None and x_fit_plot is not None:
    ax_top.plot(
        x_fit_plot, exp_func(x_fit_plot, *popt),
        "-", color="black",
        label=fr"Fit Data: A·exp(-x/τ)+B," "\n"
              + fr"τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs"
    )

ax_top.set_xlim(plot_min, plot_max)
ax_top.set_ylim(bottom=0)
ax_top.set_ylabel("Number of candidates")
ax_top.grid(alpha=0.3)
ax_top.legend()

# Bottom: ratio
finite_mask = np.isfinite(ratio) & np.isfinite(ratio_err)
ax_bottom.errorbar(
    bin_centers_common[finite_mask], ratio[finite_mask],
    yerr=ratio_err[finite_mask],
    fmt="o", color="C0",
    ecolor="C0", elinewidth=1.0, capsize=3, markersize=4
)
ax_bottom.axhline(0.3, color="k", linestyle="--", linewidth=1)
ax_bottom.axhline(-0.3, color="k", linestyle="--", linewidth=1)
ax_bottom.set_xlabel(r"$\Delta t$ [$\mu$s]")
ax_bottom.set_ylabel("(Data - MC) / Data")
ax_bottom.grid(alpha=0.3)
ax_bottom.set_ylim(-2, 2)

plt.tight_layout()
plt.show()
# Out:
# Data file: /data/halmazan/WCTE/data/AmBeCandidates/histograms_run2389_v0_5_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz
# MC file: /data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_2386_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz
# Same binning grid? False
# Scale factor (match maxima in [5.0,150.0] us): 1.849
# Seed used: A0=173.2, tau0=78
# Fit Data: A = 175.02 ± 11.72, tau = 64.76 ± 15.68 us, B = 25.50 ± 15.10
# Chi2/ndf Data = 1.67  (over 24 pts, ndf=21)

# %%
# -----------------------------
# Inputs (adjust if needed)
# -----------------------------
xmin_fit = 5.0                   # match first script
plot_min, plot_max = 0.0, 150.0
xmax_scale = 150.0

data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{sig_run}_{title}.npz"
mc_path   = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_2386_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz"

# -----------------------------
# Load Data
# -----------------------------
ddata = np.load(data_path)
bin_centers_common = ddata["bins_deltat"].astype(float)
data_vals = ddata["deltat"].astype(float)

# Keep these only for plotting, not for fitting
errors = np.sqrt(np.abs(data_vals))
errors = np.maximum(errors, 1.0)

# -----------------------------
# Load MC
# -----------------------------
dmc = np.load(mc_path)
mc_x = dmc["bins_deltat"].astype(float)
mc_y_raw = dmc["deltat"].astype(float)

# Detect whether MC bins are edges or centers
if len(mc_x) == len(mc_y_raw) + 1:
    mc_centers = 0.5 * (mc_x[:-1] + mc_x[1:])
    mc_vals = mc_y_raw
else:
    mc_centers = mc_x
    mc_vals = mc_y_raw

# Interpolate MC onto Data grid if needed
same_grid = (mc_centers.shape == bin_centers_common.shape) and np.allclose(mc_centers, bin_centers_common)
if not same_grid:
    mc_on_data_grid = np.interp(bin_centers_common, mc_centers, mc_vals, left=0.0, right=0.0)
else:
    mc_on_data_grid = mc_vals

# -----------------------------
# Scale MC to match maxima
# -----------------------------
mask_scale = (
    (bin_centers_common >= xmin_fit) &
    (bin_centers_common <= xmax_scale) &
    np.isfinite(data_vals) & np.isfinite(mc_on_data_grid)
)

max_data = np.max(data_vals[mask_scale]) if np.any(mask_scale) else np.max(data_vals)
max_mc   = np.max(mc_on_data_grid[mask_scale]) if np.any(mask_scale) else np.max(mc_on_data_grid)

scale_factor = (max_data / max_mc) if max_mc > 0 else 1.0
mc_scaled = mc_on_data_grid * scale_factor

print("Data file:", data_path)
print("MC file:", mc_path)
print("Same binning grid?", same_grid)
print(f"Scale factor (match maxima in [{xmin_fit},{xmax_scale}] us): {scale_factor:.4g}")

# -----------------------------
# Ratio panel: (Data - MC) / Data
# -----------------------------
data = data_vals.astype(float)
mc   = mc_scaled.astype(float)
data_err = errors.astype(float)

ratio = np.full_like(data, np.nan, dtype=float)
ratio_err = np.full_like(data, np.nan, dtype=float)

mask_ratio = np.isfinite(data) & np.isfinite(mc) & (data != 0)
ratio[mask_ratio] = (data[mask_ratio] - mc[mask_ratio]) / data[mask_ratio]
ratio_err[mask_ratio] = data_err[mask_ratio] / np.abs(data[mask_ratio])

# -----------------------------
# Fit exponential: same style as first script
# -----------------------------
def exp_func(x, A, tau, B):
    return A * np.exp(-x / tau) + B

# Match first script mask logic as closely as possible
mask_fit = (
    (bin_centers_common > xmin_fit) &
    np.isfinite(data)
)

if np.sum(mask_fit) >= 4:
    x_fit_data = bin_centers_common[mask_fit]
    y_fit_data = data[mask_fit]

    # Same seed philosophy as first script
    tau0 = np.mean(x_fit_data)       # in first script this was np.mean(df.DeltaT.values)
    A0   = np.max(data)
    B0   = np.min(data)
    p0   = (A0, tau0, B0)

    # IMPORTANT: no sigma -> unweighted fit, like first script
    popt, pcov = curve_fit(
        exp_func,
        x_fit_data,
        y_fit_data,
        p0=p0,
        maxfev=20000
    )

    A_fit, tau_fit, B_fit = popt
    A_err, tau_err, B_err = np.sqrt(np.diag(pcov))

    print(f"Seed used: A0={A0:.4g}, tau0={tau0:.4g}")
    print(f"Fit Data: A = {A_fit:.2f} ± {A_err:.2f}, tau = {tau_fit:.2f} ± {tau_err:.2f} us, B = {B_fit:.2f} ± {B_err:.2f}")

    x_fit_plot = np.linspace(max(xmin_fit, plot_min), plot_max, 400)
else:
    popt = None
    x_fit_plot = None
    print("Fit skipped: not enough valid bins for A*exp(-x/tau)+B fit.")

# -----------------------------
# Optional chi2/ndf using plotting errors
# -----------------------------
def chi2_ndf(y_obs, y_err, y_exp, n_params):
    mask = np.isfinite(y_obs) & np.isfinite(y_err) & np.isfinite(y_exp) & (y_err > 0)
    n = int(np.sum(mask))
    if n <= n_params:
        return np.nan, n, n - n_params
    chi2 = np.sum(((y_obs[mask] - y_exp[mask]) / y_err[mask])**2)
    ndf = n - n_params
    return chi2 / ndf, n, ndf

if popt is not None:
    y_model_data = exp_func(x_fit_data, *popt)
    redchi2_data, npts_data, ndf_data = chi2_ndf(
        y_fit_data,
        data_err[mask_fit],
        y_model_data,
        n_params=3
    )
    print(f"Chi2/ndf Data = {redchi2_data:.2f}  (over {npts_data} pts, ndf={ndf_data})")
else:
    redchi2_data = np.nan

# -----------------------------
# Plot
# -----------------------------
fig, (ax_top, ax_bottom) = plt.subplots(
    2, 1, sharex=True,
    gridspec_kw={"height_ratios": [3, 1]},
    figsize=(10, 8)
)

# Top: Data + MC
ax_top.errorbar(
    bin_centers_common, data, yerr=data_err,
    fmt="o", color="C0",
    ecolor="C0", elinewidth=1.5, capsize=3, markersize=6,
    label="Data (signal - bkg)"
)

ax_top.step(
    bin_centers_common, mc, where="post",
    linewidth=2, color="red",
    label="MC (scaled)"
)

if popt is not None and x_fit_plot is not None:
    ax_top.plot(
        x_fit_plot, exp_func(x_fit_plot, *popt),
        "-", color="black",
        label=fr"Fit Data: A·exp(-x/τ)+B"
              + "\n"
              + fr"τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs, "
              + fr"$\chi^2/\mathrm{{ndf}}$ = {redchi2_data:.2f}"
    )

ax_top.set_xlim(plot_min, plot_max)
ax_top.set_ylim(bottom=0)
ax_top.set_ylabel("Number of candidates")
ax_top.grid(alpha=0.3)
ax_top.legend()

# Bottom: ratio
finite_mask = np.isfinite(ratio) & np.isfinite(ratio_err)
ax_bottom.errorbar(
    bin_centers_common[finite_mask], ratio[finite_mask],
    yerr=ratio_err[finite_mask],
    fmt="o", color="C0",
    ecolor="C0", elinewidth=1.0, capsize=3, markersize=4
)
ax_bottom.axhline(0.3, color="k", linestyle="--", linewidth=1)
ax_bottom.axhline(-0.3, color="k", linestyle="--", linewidth=1)
ax_bottom.set_xlabel(r"$\Delta t$ [$\mu$s]")
ax_bottom.set_ylabel("(Data - MC) / Data")
ax_bottom.grid(alpha=0.3)
ax_bottom.set_ylim(-2, 2)

plt.tight_layout()
plt.show()
# Out:
# Data file: /data/halmazan/WCTE/data/AmBeCandidates/histograms_run2389_v0_5_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz
# MC file: /data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_2386_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz
# Same binning grid? False
# Scale factor (match maxima in [5.0,150.0] us): 1.849
# Seed used: A0=173.2, tau0=78
# Fit Data: A = 175.02 ± 11.72, tau = 64.76 ± 15.68 us, B = 25.50 ± 15.10
# Chi2/ndf Data = 1.67  (over 24 pts, ndf=21)

# %%
# -----------------------------
# Inputs (ajusta si hace falta)
# -----------------------------
xmin_fit = 8.0
plot_min, plot_max = 0.0, 150.0
xmax_scale = 150.0

data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{sig_run}_{title}.npz"
mc_path   = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_2386_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz"

# -----------------------------
# Load Data (tu última distribución)
# -----------------------------
ddata = np.load(data_path)
bin_centers_common = ddata["bins_deltat"].astype(float)   # centros
data_vals = ddata["deltat"].astype(float)                 # (scaled_sig - bkg) ya binned

# Errores (proxy Poisson si no guardaste los errores)
# Si hay negativos, usamos sqrt(|N|) como aproximación + mínimo 1 (misma estética de "siempre visible").
errors = np.sqrt(np.abs(data_vals))
errors = np.maximum(errors, 1.0)

# -----------------------------
# Load MC
# -----------------------------
dmc = np.load(mc_path)
mc_x = dmc["bins_deltat"].astype(float)
mc_y_raw = dmc["deltat"].astype(float)

# Detectar si bins_deltat en MC son edges (N+1) o centros (N)
if len(mc_x) == len(mc_y_raw) + 1:
    mc_centers = 0.5 * (mc_x[:-1] + mc_x[1:])
    mc_vals = mc_y_raw
else:
    mc_centers = mc_x
    mc_vals = mc_y_raw

# Interpolar MC al grid de Data si hace falta
same_grid = (mc_centers.shape == bin_centers_common.shape) and np.allclose(mc_centers, bin_centers_common)
if not same_grid:
    mc_on_data_grid = np.interp(bin_centers_common, mc_centers, mc_vals, left=0.0, right=0.0)
else:
    mc_on_data_grid = mc_vals

# -----------------------------
# Escalado tipo "match maxima" en ventana [xmin_fit, xmax_scale]
# -----------------------------
mask_scale = (
    (bin_centers_common >= xmin_fit) &
    (bin_centers_common <= xmax_scale) &
    np.isfinite(data_vals) & np.isfinite(mc_on_data_grid)
)

max_data = np.max(data_vals[mask_scale]) if np.any(mask_scale) else np.max(data_vals)
max_mc   = np.max(mc_on_data_grid[mask_scale]) if np.any(mask_scale) else np.max(mc_on_data_grid)

scale_factor = (max_data / max_mc) if max_mc > 0 else 1.0
mc_scaled = mc_on_data_grid * scale_factor

print("Data file:", data_path)
print("MC file:", mc_path)
print("Same binning grid?", same_grid)
print(f"Scale factor (match maxima in [{xmin_fit},{xmax_scale}] us): {scale_factor:.4g}")

# -----------------------------
# Ratio panel: (Data - MC) / Data
# -----------------------------
data = data_vals.astype(float)
mc   = mc_scaled.astype(float)
data_err = errors.astype(float)

ratio = np.full_like(data, np.nan, dtype=float)
ratio_err = np.full_like(data, np.nan, dtype=float)

mask_ratio = np.isfinite(data) & np.isfinite(mc) & (data != 0)
ratio[mask_ratio] = (data[mask_ratio] - mc[mask_ratio]) / data[mask_ratio]

# Propagación simple: sigma_ratio ≈ sigma_data/|data|
ratio_err[mask_ratio] = data_err[mask_ratio] / np.abs(data[mask_ratio])

# -----------------------------
# Fit exponencial: A*exp(-x/tau) + B  (como tu script original)
# -----------------------------
def exp_func(x, A, tau, B):
    return A * np.exp(-x / tau) + B

# Máscara de fit: x>xmin_fit, errores finitos y >0
mask_fit = (
    (bin_centers_common > xmin_fit) &
    np.isfinite(data_err) & (data_err > 0) &
    np.isfinite(data) & np.isfinite(mc)
    # opcional (a veces ayuda):
    # & (data > 0) & (mc > 0)
)

# Ajuste si hay suficientes puntos
if np.sum(mask_fit) >= 6:
    x_fit_data = bin_centers_common[mask_fit]
    y_fit_data = data[mask_fit]
    s_fit_data = data_err[mask_fit]

    # Seeds razonables (similar a lo que haces):
    tau0 = np.mean(x_fit_data) if len(x_fit_data) else 500.0
    A0   = np.nanmax(y_fit_data)
    B0   = np.nanmin(y_fit_data)
    p0   = (A0, tau0, B0)

    # Fit Data (con sigma y absolute_sigma para errores correctos)
    popt, pcov = curve_fit(
        exp_func, x_fit_data, y_fit_data,
        p0=p0, sigma=s_fit_data, absolute_sigma=True,
        maxfev=20000
    )
    A_fit, tau_fit, B_fit = popt
    A_err, tau_err, B_err = np.sqrt(np.diag(pcov))

    print(f"Fit Data: A = {A_fit:.2f} ± {A_err:.2f}, tau = {tau_fit:.2f} ± {tau_err:.2f} us, B = {B_fit:.2f} ± {B_err:.2f}")

    # Fit MC (scaled): usamos un error proxy (sqrt(|mc|)) para no dejar sigma vacía
    mc_err = np.sqrt(np.abs(mc))
    mc_err = np.maximum(mc_err, 1.0)

    x_fit_mc = bin_centers_common[mask_fit]
    y_fit_mc = mc[mask_fit]
    s_fit_mc = mc_err[mask_fit]

    tau0_mc = np.mean(x_fit_mc) if len(x_fit_mc) else 500.0
    A0_mc   = np.nanmax(y_fit_mc)
    B0_mc   = np.nanmin(y_fit_mc)
    p0_mc   = (A0_mc, tau0_mc, B0_mc)

    popt_mc, pcov_mc = curve_fit(
        exp_func, x_fit_mc, y_fit_mc,
        p0=p0_mc, sigma=s_fit_mc, absolute_sigma=True,
        maxfev=20000
    )
    A_fit_mc, tau_fit_mc, B_fit_mc = popt_mc
    A_err_mc, tau_err_mc, B_err_mc = np.sqrt(np.diag(pcov_mc))

    print(f"Fit MC  : A = {A_fit_mc:.2f} ± {A_err_mc:.2f}, tau = {tau_fit_mc:.2f} ± {tau_err_mc:.2f} us, B = {B_fit_mc:.2f} ± {B_err_mc:.2f}")

    x_fit_plot = np.linspace(max(xmin_fit, plot_min), plot_max, 400)
else:
    popt = popt_mc = None
    x_fit_plot = None
    print("Fit skipped: not enough valid bins for A*exp(-x/tau)+B fit.")

# -----------------------------
# Chi2 / ndf (weighted) for the fitted model
# -----------------------------
def chi2_ndf(y_obs, y_err, y_exp, n_params):
    mask = np.isfinite(y_obs) & np.isfinite(y_err) & np.isfinite(y_exp) & (y_err > 0)
    n = int(np.sum(mask))
    if n <= n_params:
        return np.nan, n, n - n_params
    chi2 = np.sum(((y_obs[mask] - y_exp[mask]) / y_err[mask])**2)
    ndf = n - n_params
    return chi2 / ndf, n, ndf

if popt is not None:
    # Data chi2/ndf on the same points used for the fit
    y_model_data = exp_func(x_fit_data, *popt)
    redchi2_data, npts_data, ndf_data = chi2_ndf(y_fit_data, s_fit_data, y_model_data, n_params=3)

    # MC chi2/ndf
    y_model_mc = exp_func(x_fit_mc, *popt_mc)
    redchi2_mc, npts_mc, ndf_mc = chi2_ndf(y_fit_mc, s_fit_mc, y_model_mc, n_params=3)

    print(f"Chi2/ndf Data = {redchi2_data:.2f}  (chi2/ndf over {npts_data} pts, ndf={ndf_data})")
    print(f"Chi2/ndf MC   = {redchi2_mc:.2f}  (chi2/ndf over {npts_mc} pts, ndf={ndf_mc})")
else:
    print("Chi2/ndf not computed (fit was skipped).")

# -----------------------------
# Plot (2 paneles, misma estética)
# -----------------------------
fig, (ax_top, ax_bottom) = plt.subplots(
    2, 1, sharex=True,
    gridspec_kw={"height_ratios": [3, 1]},
    figsize=(10, 8)
)

# Top: Data + MC
ax_top.errorbar(
    bin_centers_common, data, yerr=data_err,
    fmt="o", color="C0",
    ecolor="C0", elinewidth=1.5, capsize=3, markersize=6,
    label="Data (signal - bkg)"
)

ax_top.step(
    bin_centers_common, mc, where="post",
    linewidth=2, color="red",
    label="MC (scaled)"
)

# Dibujamos el fit de Data (negro) como en tu ejemplo
if popt is not None and x_fit_plot is not None:
    ax_top.plot(
        x_fit_plot, exp_func(x_fit_plot, *popt),
        "-", color="black",
        label=fr"Fit Data: A·exp(-x/τ)+B," \
      f"\n" + fr"τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs, $\chi^2/\mathrm{{ndf}}$ = {redchi2_data:.2f}"
    )

ax_top.set_xlim(plot_min, plot_max)
ax_top.set_ylim(bottom=0)
ax_top.set_ylabel("Number of candidates")
ax_top.grid(alpha=0.3)
ax_top.legend()

# Bottom: ratio
finite_mask = np.isfinite(ratio) & np.isfinite(ratio_err)
ax_bottom.errorbar(
    bin_centers_common[finite_mask], ratio[finite_mask],
    yerr=ratio_err[finite_mask],
    fmt="o", color="C0",
    ecolor="C0", elinewidth=1.0, capsize=3, markersize=4
)
ax_bottom.axhline(0.3, color="k", linestyle="--", linewidth=1)
ax_bottom.axhline(-0.3, color="k", linestyle="--", linewidth=1)
ax_bottom.set_xlabel(r"$\Delta t$ [$\mu$s]")
ax_bottom.set_ylabel("(Data - MC) / Data")
ax_bottom.grid(alpha=0.3)
ax_bottom.set_ylim(-2, 2)

plt.tight_layout()
plt.show()
# Out:
# Data file: /data/halmazan/WCTE/data/AmBeCandidates/histograms_run2389_v0_5_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz
# MC file: /data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_2386_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz
# Same binning grid? False
# Scale factor (match maxima in [8.0,150.0] us): 1.849
# Fit Data: A = 173.01 ± 9.24, tau = 63.30 ± 12.00 us, B = 25.98 ± 10.18
# Fit MC  : A = 195.34 ± 9.92, tau = 48.51 ± 5.13 us, B = 1.89 ± 4.20
# Chi2/ndf Data = 1.65  (chi2/ndf over 24 pts, ndf=21)
# Chi2/ndf MC   = 0.80  (chi2/ndf over 24 pts, ndf=21)

# %%
def load_hist_and_bins(npz_path, var):
    d = np.load(npz_path)
    y = d[var].astype(float)
    x = d[f"bins_{var}"].astype(float)
    return x, y

def ensure_centers(x, y):
    """
    If x has length N+1 and y has length N, interpret x as edges and convert to centers.
    Otherwise assume x already contains centers.
    """
    if len(x) == len(y) + 1:
        return 0.5 * (x[:-1] + x[1:]), y
    return x, y

def plot_data_vs_mc(
    data_path,
    mc_path,
    var,
    title="",
    xlabel=None,
    ylabel="Counts (a.u.)",
    plot_min=None,
    plot_max=None,
    scale_mode="max",          # "max" or "area" or None
    scale_window=None,         # tuple (xmin, xmax) or None (use full range)
    mc_color="red",
    data_color="C0",
    step_where="post",
):
    # ---- Load
    x_data_raw, y_data = load_hist_and_bins(data_path, var)
    x_mc_raw,   y_mc   = load_hist_and_bins(mc_path, var)

    x_data, y_data = ensure_centers(x_data_raw, y_data)
    x_mc,   y_mc   = ensure_centers(x_mc_raw,   y_mc)

    # ---- Put MC on data grid if needed
    same_grid = (x_data.shape == x_mc.shape) and np.allclose(x_data, x_mc)
    if same_grid:
        mc_on_data = y_mc.copy()
    else:
        mc_on_data = np.interp(x_data, x_mc, y_mc, left=0.0, right=0.0)

    # ---- Scale MC (optional)
    mc_scaled = mc_on_data.copy()
    scale_factor = 1.0

    if scale_mode is not None:
        if scale_window is None:
            m = np.isfinite(y_data) & np.isfinite(mc_on_data)
        else:
            xmin, xmax = scale_window
            m = (
                (x_data >= xmin) & (x_data <= xmax) &
                np.isfinite(y_data) & np.isfinite(mc_on_data)
            )

        if np.any(m):
            if scale_mode == "max":
                denom = np.max(mc_on_data[m])
                numer = np.max(y_data[m])
                scale_factor = (numer / denom) if denom > 0 else 1.0
            elif scale_mode == "area":
                denom = np.sum(mc_on_data[m])
                numer = np.sum(y_data[m])
                scale_factor = (numer / denom) if denom != 0 else 1.0
            else:
                raise ValueError("scale_mode must be one of: 'max', 'area', None")

            mc_scaled = mc_on_data * scale_factor

    # ---- Errors for data (simple proxy)
    yerr = np.sqrt(np.abs(y_data))
    yerr = np.maximum(yerr, 1.0)

    # ---- Plot
    fig, ax = plt.subplots(figsize=(10, 8))

    ax.step(
        x_data, y_data, where=step_where,
        linewidth=2.0, color=data_color,
        label="Data"
    )
    ax.step(
        x_data, mc_scaled, where=step_where,
        linewidth=2, color=mc_color,
        label=f"MC (scaled)" if scale_mode else "MC"
    )

    if plot_min is not None or plot_max is not None:
        ax.set_xlim(plot_min if plot_min is not None else np.min(x_data),
                    plot_max if plot_max is not None else np.max(x_data))

    ax.set_ylim(bottom=0)
    ax.set_xlabel(xlabel if xlabel is not None else var)
    ax.set_ylabel(ylabel)
    ax.set_title(title if title else f"{var}: Data vs MC")
    ax.grid(alpha=0.3)
    ax.legend()
    plt.tight_layout()
    plt.show()

    return scale_factor, same_grid

def plot_data_vs_mc(
    data_path,
    mc_path,
    var,
    title="",
    xlabel=None,
    ylabel="Counts (a.u.)",
    plot_min=None,
    plot_max=None,
    scale_mode="max",          # "max" or "area" or None
    scale_window=None,         # tuple (xmin, xmax) or None (use plot range if set, else full range)
    mc_color="red",
    data_color="C0",
    step_where="post",
):
    # ---- Load
    x_data_raw, y_data = load_hist_and_bins(data_path, var)
    x_mc_raw,   y_mc   = load_hist_and_bins(mc_path, var)

    x_data, y_data = ensure_centers(x_data_raw, y_data)
    x_mc,   y_mc   = ensure_centers(x_mc_raw,   y_mc)

    # ---- Put MC on data grid if needed
    same_grid = (x_data.shape == x_mc.shape) and np.allclose(x_data, x_mc)
    if same_grid:
        mc_on_data = y_mc.copy()
    else:
        mc_on_data = np.interp(x_data, x_mc, y_mc, left=0.0, right=0.0)

    # ---- Define visible x-range for plotting
    x_plot_min = plot_min if plot_min is not None else np.min(x_data)
    x_plot_max = plot_max if plot_max is not None else np.max(x_data)

    # ---- Scale MC (optional)
    mc_scaled = mc_on_data.copy()
    scale_factor = 1.0

    if scale_mode is not None:
        # explicit scale_window overrides plot range
        if scale_window is not None:
            xmin, xmax = scale_window
        else:
            xmin, xmax = x_plot_min, x_plot_max

        m = (
            (x_data >= xmin) & (x_data <= xmax) &
            np.isfinite(y_data) & np.isfinite(mc_on_data)
        )

        if np.any(m):
            if scale_mode == "max":
                denom = np.max(mc_on_data[m])
                numer = np.max(y_data[m])
                scale_factor = (numer / denom) if denom > 0 else 1.0
            elif scale_mode == "area":
                denom = np.sum(mc_on_data[m])
                numer = np.sum(y_data[m])
                scale_factor = (numer / denom) if denom != 0 else 1.0
            else:
                raise ValueError("scale_mode must be one of: 'max', 'area', None")

            mc_scaled = mc_on_data * scale_factor

    # ---- Errors for data (simple proxy)
    yerr = np.sqrt(np.abs(y_data))
    yerr = np.maximum(yerr, 1.0)

    # ---- Plot
    fig, ax = plt.subplots(figsize=(10, 8))

    ax.step(
        x_data, y_data, where=step_where,
        linewidth=2.0, color=data_color,
        label="Data"
    )
    ax.step(
        x_data, mc_scaled, where=step_where,
        linewidth=2, color=mc_color,
        label=f"MC (scaled)" if scale_mode else "MC"
    )

    # ---- Apply x-limits
    ax.set_xlim(x_plot_min, x_plot_max)

    # ---- Compute y-limits only from visible region
    m_vis = (
        (x_data >= x_plot_min) & (x_data <= x_plot_max) &
        np.isfinite(y_data) & np.isfinite(mc_scaled)
    )

    if np.any(m_vis):
        ymax_vis = max(np.max(y_data[m_vis]), np.max(mc_scaled[m_vis]))
        ax.set_ylim(0, 1.1 * ymax_vis if ymax_vis > 0 else 1.0)
    else:
        ax.set_ylim(0, 1.0)

    ax.set_xlabel(xlabel if xlabel is not None else var)
    ax.set_ylabel(ylabel)
    ax.set_title(title if title else f"{var}: Data vs MC")
    ax.grid(alpha=0.3)
    ax.legend()
    plt.tight_layout()
    plt.show()

    return scale_factor, same_grid

# %%
title
# Out:
# 'v0_5_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF'

# %%
data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{sig_run}_{title}.npz"
mc_path   = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_{sig_run}_prompt50threshold_prompt1000window_tmeanlimits_neutronsel_mult_wtfilter_w10ns_mtrms10_wTOF.npz"

plot_data_vs_mc(data_path, mc_path, var="deltaR",       xlabel=r"$\Delta R$ [cm]", title="deltaR", scale_mode=None)
plot_data_vs_mc(data_path, mc_path, var="prompt_nhits", xlabel="nHits",   title="Prompt Candidates", plot_min=50, plot_max=300, scale_mode=None)
plot_data_vs_mc(data_path, mc_path, var="delayed_nhits",xlabel="nHits",  title="Delayed Candidates", plot_min=10, plot_max=50, scale_mode=None)
plot_data_vs_mc(data_path, mc_path, var="prompt_trms",  xlabel="tRMS [ns]",    title="Prompt Candidates", scale_mode="max")
plot_data_vs_mc(data_path, mc_path, var="delayed_trms", xlabel="tRMS [ns]",   title="Delayed Candidates", scale_mode=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb Cell 115 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y222sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{sig_run}_{title}.npz"
# ...

# %%
runs = ['MC', '2386', '2387', '2388', '2389']
var = "deltaR"

xlabel = r"$\Delta R$ [cm]"
ylabel = "Counts"
title = "Capture distance with respect to source deployed"
step_where = "mid"

# Paleta colorblind-friendly (Okabe-Ito)
cb_colors = [
    "#0072B2",  # blue
    "#E69F00",  # orange
    "#009E73",  # green
    "#CC79A7",  # purple
    "#56B4E9",  # sky blue
    "#F0E442",  # yellow
    "#D55E00",  # vermillion
]

# Guardar histogramas cargados
hist_data = {}

for ri in runs:
    if ri == 'MC':
        data_path = "/data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_promptvar_neutronsel_mult_wtfilter_w10ns_mtrms10.npz"
    else:
        data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{ri}_promptvar_neutronsel_mult_wtfilter_w10ns_mtrms10_noTOF.npz"

    x_data, y_data = load_hist_and_bins(data_path, var)
    hist_data[ri] = (x_data, y_data)

# Escalar MC al máximo de run 2389
x_mc, y_mc = hist_data['MC']
x_2389, y_2389 = hist_data['2389']

mc_max = np.max(y_mc)
run2389_max = np.max(y_2389)

if mc_max > 0:
    scale_factor = run2389_max / mc_max
else:
    scale_factor = 1.0

hist_data['MC'] = (x_mc, y_mc * scale_factor)

fig, ax = plt.subplots(figsize=(10, 8))

color_idx = 0

for ri in runs:
    x_data, y_data = hist_data[ri]

    if ri == 'MC':
        label = f"MC (scaled ×{scale_factor:.2f})"
        color = "red"
        linestyle = "-"
        linewidth = 2.5
    else:
        label = f"Run {ri}"
        color = cb_colors[color_idx % len(cb_colors)]
        linestyle = "--"
        linewidth = 2.0
        color_idx += 1

    ax.step(
        x_data,
        y_data,
        where=step_where,
        linewidth=linewidth,
        linestyle=linestyle,
        color=color,
        label=label
    )

ax.set_ylim(bottom=0)
ax.set_xlabel(xlabel if xlabel is not None else var)
ax.set_ylabel(ylabel)
ax.set_title(title if title else f"{var}: Data vs MC")
ax.grid(alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
runs = ['MC', '2386', '2387', '2388', '2389']
var = "deltat"

xlabel = r"$\Delta t$ [$\mu$s]"
ylabel = "Counts"
plot_title = "Capture time with respect to selected prompt"
step_where = "mid"

# Paleta colorblind-friendly (Okabe-Ito)
cb_colors = [
    "#0072B2",  # blue
    "#E69F00",  # orange
    "#009E73",  # green
    "#CC79A7",  # purple
    "#56B4E9",  # sky blue
    "#F0E442",  # yellow
    "#D55E00",  # vermillion
]

# Guardar histogramas cargados
hist_data = {}

for ri in runs:
    if ri == 'MC':
        data_path = "/data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_promptvar_neutronsel_mult_wtfilter_w10ns_mtrms10.npz"
    else:
        data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{ri}_{title}.npz"

    x_data, y_data = load_hist_and_bins(data_path, var)
    hist_data[ri] = (x_data, y_data)

# Escalar MC al máximo de run 2389
x_mc, y_mc = hist_data['MC']
x_2389, y_2389 = hist_data['2389']

mc_max = np.max(y_mc)
run2389_max = np.max(y_2389)

if mc_max > 0:
    scale_factor = run2389_max / mc_max
else:
    scale_factor = 1.0

hist_data['MC'] = (x_mc, y_mc * scale_factor)

fig, ax = plt.subplots(figsize=(10, 8))

color_idx = 0

for ri in runs:
    x_data, y_data = hist_data[ri]

    if ri == 'MC':
        label = f"MC (scaled ×{scale_factor:.2f})"
        color = "red"
        linestyle = "-"
        linewidth = 2.5
    else:
        label = f"Run {ri}"
        color = cb_colors[color_idx % len(cb_colors)]
        linestyle = "--"
        linewidth = 2.0
        color_idx += 1

    ax.step(
        x_data,
        y_data,
        where=step_where,
        linewidth=linewidth,
        linestyle=linestyle,
        color=color,
        label=label
    )

ax.set_ylim(bottom=0)
ax.set_xlabel(xlabel if xlabel is not None else var)
ax.set_ylabel(ylabel)
ax.set_title(plot_title if title else f"{var}: Data vs MC")
ax.grid(alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb Cell 117 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y224sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>     else:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y224sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>         data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{ri}_{title}.npz"
# ...

# %%
runs = ['MC', '2386', '2387', '2388', '2389']
var = "prompt_trms"

xlabel = r"$t_{RMS}$ [ns]"
ylabel = "Counts"
plot_title = "Prompt"
step_where = "mid"

# Paleta colorblind-friendly (Okabe-Ito)
cb_colors = [
    "#0072B2",  # blue
    "#E69F00",  # orange
    "#009E73",  # green
    "#CC79A7",  # purple
    "#56B4E9",  # sky blue
    "#F0E442",  # yellow
    "#D55E00",  # vermillion
]

# Guardar histogramas cargados
hist_data = {}

for ri in runs:
    if ri == 'MC':
        data_path = "/data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_promptvar_neutronsel_mult_wtfilter_w10ns_mtrms10.npz"
    else:
        data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{ri}_{title}.npz"

    x_data, y_data = load_hist_and_bins(data_path, var)
    hist_data[ri] = (x_data, y_data)

# Escalar MC al máximo de run 2389
x_mc, y_mc = hist_data['MC']
x_2389, y_2389 = hist_data['2389']

mc_max = np.max(y_mc)
run2389_max = np.max(y_2389)

if mc_max > 0:
    scale_factor = run2389_max / mc_max
else:
    scale_factor = 1.0

hist_data['MC'] = (x_mc, y_mc * scale_factor)

fig, ax = plt.subplots(figsize=(10, 8))

color_idx = 0

for ri in runs:
    x_data, y_data = hist_data[ri]

    if ri == 'MC':
        label = f"MC (scaled ×{scale_factor:.2f})"
        color = "red"
        linestyle = "-"
        linewidth = 2.5
    else:
        label = f"Run {ri}"
        color = cb_colors[color_idx % len(cb_colors)]
        linestyle = "--"
        linewidth = 2.0
        color_idx += 1

    ax.step(
        x_data,
        y_data,
        where=step_where,
        linewidth=linewidth,
        linestyle=linestyle,
        color=color,
        label=label
    )

ax.set_ylim(bottom=0)
ax.set_xlabel(xlabel if xlabel is not None else var)
ax.set_ylabel(ylabel)
ax.set_title(plot_title if title else f"{var}: Data vs MC")
ax.grid(alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
runs = ['MC', '2386', '2387', '2388', '2389']
var = "prompt_nhits"

xlabel = r"nHits"
ylabel = "Counts"
plot_title = "Prompt"
step_where = "mid"

# Paleta colorblind-friendly (Okabe-Ito)
cb_colors = [
    "#0072B2",  # blue
    "#E69F00",  # orange
    "#009E73",  # green
    "#CC79A7",  # purple
    "#56B4E9",  # sky blue
    "#F0E442",  # yellow
    "#D55E00",  # vermillion
]

# Guardar histogramas cargados
hist_data = {}

for ri in runs:
    if ri == 'MC':
        data_path = "/data/halmazan/WCTE/data/AmBeCandidates/histograms_MC_promptvar_neutronsel_mult_wtfilter_w10ns_mtrms10.npz"
    else:
        data_path = f"/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{ri}_{title}.npz"

    x_data, y_data = load_hist_and_bins(data_path, var)
    hist_data[ri] = (x_data, y_data)

# Escalar MC al máximo de run 2389
x_mc, y_mc = hist_data['MC']
x_2389, y_2389 = hist_data['2389']

mc_max = np.max(y_mc)
run2389_max = np.max(y_2389)

if mc_max > 0:
    scale_factor = run2389_max / mc_max
else:
    scale_factor = 1.0

hist_data['MC'] = (x_mc, y_mc * scale_factor)

fig, ax = plt.subplots(figsize=(10, 8))

color_idx = 0

for ri in runs:
    x_data, y_data = hist_data[ri]

    if ri == 'MC':
        label = f"MC (scaled ×{scale_factor:.2f})"
        color = "red"
        linestyle = "-"
        linewidth = 2.5
    else:
        label = f"Run {ri}"
        color = cb_colors[color_idx % len(cb_colors)]
        linestyle = "--"
        linewidth = 2.0
        color_idx += 1

    ax.step(
        x_data,
        y_data,
        where=step_where,
        linewidth=linewidth,
        linestyle=linestyle,
        color=color,
        label=label
    )

ax.set_ylim(bottom=0)
ax.set_xlabel(xlabel if xlabel is not None else var)
ax.set_ylabel(ylabel)
ax.set_title(plot_title if title else f"{var}: Data vs MC")
ax.grid(alpha=0.3)
ax.legend()

plt.tight_layout()
plt.show()

# %%
positions = ["Pos 1", "Pos 2", "Pos 3", "Pos 4"]#, "Pos 5"]

cap_bkg = [82, 73, 77, 79 ]#, 52]
cap_bkg_err = [4, 3, 3, 4]#, 4]

cap_mc = 64.6
cap_mc_err = 0.1

fig, ax = plt.subplots(figsize=(8,5))

# Data errorbars (use consistent color cycle for accessibility)
ax.errorbar(positions, cap_bkg, yerr=cap_bkg_err, fmt='p--',)


# Horizontal line for MC central value
ax.axhline(cap_mc, color='k', linestyle='--', linewidth=1.5, label='MC')

# Shaded band for MC uncertainty (drawn across full x-range)
xmin, xmax = ax.get_xlim()           # acquire axis limits after plotting
ax.fill_between([xmin, xmax],       # x-range
                cap_mc - cap_mc_err,
                cap_mc + cap_mc_err,
                color='k', alpha=0.12, linewidth=0)


handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles)
ax.set_ylim(60, 90)

ax.set_xlabel("Position")
ax.set_ylabel(r"Capture Time [$\mu$s]")

ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Runs and efficiencies
runs = ['2386', '2387', '2388', '2389']
eff = np.array([82, 73, 77, 79])#, 52])

# XYZ positions for each run
positions = {
    '2386': [0.0,     30.5, 0.0],
    '2387': [0.0,     -30.5, 0.0],
    '2388': [0.0,      -58.5, 0.0],
    '2389': [-47.64, +30.5, 29.17],
    #'2390': [-47.64, -30.5, 29.17]
}

# Extract X and Z for projection
xs = np.array([positions[r][0] for r in runs])
ys = np.array([positions[r][2] for r in runs])
zs = np.array([positions[r][1] for r in runs])

# Plot
plt.figure(figsize=(7,6))
sc = plt.scatter(xs, zs, c=eff, s=300, edgecolor='black')

# Add run number labels
for r, x, z in zip(runs, xs, zs):
    plt.text(x+1, z+1, r, fontsize=10)

plt.xlabel("X [cm]")
plt.ylabel("Y [cm]")
plt.title("Neutron Capture Time")

plt.ylim(-150, 150)  # Set x-axis limits
plt.xlim(-150, 150)

# Colorbar
cbar = plt.colorbar(sc)
cbar.set_label(r"Capture Time [$\mu$s]")

plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
# Runs and efficiencies
runs = ['2387', '2390']
eff = np.array([65, 52])

# XYZ positions for each run
positions = {
    '2385': [0.0,     30.5, 0.0],
    '2386': [0.0,     -30.5, 0.0],
    '2387': [0.0,      -58.5, 0.0],
    '2388': [-47.64, +30.5, 29.17],
    '2389': [-47.64, -30.5, 29.17]
}

# Extract X and Z for projection
xs = np.array([positions[r][0] for r in runs])
ys = np.array([positions[r][2] for r in runs])
zs = np.array([positions[r][1] for r in runs])

# Plot
plt.figure(figsize=(7,6))
sc = plt.scatter(xs, ys, c=eff, s=300, edgecolor='black')

# Add run number labels
for r, x, z in zip(runs, xs, zs):
    plt.text(x+1, z+1, r, fontsize=10)

plt.xlabel("X [cm]")
plt.ylabel("Z [cm]")
plt.title("Neutron Capture Time")

plt.ylim(-150, 150)  # Set x-axis limits
plt.xlim(-150, 150)

# Colorbar
cbar = plt.colorbar(sc)
cbar.set_label(r"Capture Time [$\mu$s]")

plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb Cell 120 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y225sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> positions = {
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y225sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     '2385': [0.0,     30.5, 0.0],
# ...

# %%
# Runs and efficiencies
runs = ['2386', '2387', '2388', '2389']
eff = np.array([27.1, 28.6, 31.34, 31.14])

# XYZ positions for each run
positions = {
    '2386': [0.0,     30.5, 0.0],
    '2387': [0.0,     -30.5, 0.0],
    '2388': [0.0,      -58.5, 0.0],
    '2389': [-47.64, +30.5, 29.17],
    #'2390': [-47.64, -30.5, 29.17]
}

# Extract X and Z for projection
xs = np.array([positions[r][0] for r in runs])
ys = np.array([positions[r][2] for r in runs])
zs = np.array([positions[r][1] for r in runs])

# Plot
plt.figure(figsize=(7,6))
sc = plt.scatter(xs, zs, c=eff, s=300, edgecolor='black')

# Add run number labels
for r, x, z in zip(runs, xs, zs):
    plt.text(x+1, z+1, r, fontsize=10)

plt.xlabel("X [cm]")
plt.ylabel("Y [cm]")
plt.title("Neutron Capture Efficiency")

plt.ylim(-150, 150)  # Set x-axis limits
plt.xlim(-150, 150)

# Colorbar
cbar = plt.colorbar(sc)
cbar.set_label("Efficiency [%]")

plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
# Runs and efficiencies
runs = ['2386', '2389']
eff = np.array([45.45, 52.42])

# XYZ positions for each run
positions = {
    '2385': [0.0,     30.5, 0.0],
    '2386': [0.0,     -30.5, 0.0],
    '2387': [0.0,      -58.5, 0.0],
    '2388': [-47.64, +30.5, 29.17],
    '2389': [-47.64, -30.5, 29.17]
}

# Extract X and Z for projection
xs = np.array([positions[r][0] for r in runs])
ys = np.array([positions[r][2] for r in runs])
zs = np.array([positions[r][1] for r in runs])

# Plot
plt.figure(figsize=(7,6))
sc = plt.scatter(xs, ys, c=eff, s=300, edgecolor='black')

# Add run number labels
for r, x, z in zip(runs, xs, zs):
    plt.text(x+1, z+1, r, fontsize=10)

plt.xlabel("X [cm]")
plt.ylabel("Z [cm]")
plt.title("Neutron Capture Efficiency")

plt.ylim(-150, 150)  # Set x-axis limits
plt.xlim(-150, 150)

# Colorbar
cbar = plt.colorbar(sc)
cbar.set_label("Efficiency [%]")

plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
positions = ["Pos 1", "Pos 2", "Pos 3", "Pos 4"]

# Values from the table
#sig = [6146, 11565, 15298, 16522, 15390]
sig = [77738, 100057, 105021, 95945]
sig_err = []
for sig_i in sig:
    sig_err.append(np.sqrt(sig_i))

#bkg = 3244
bkg = 2843
bkg_err = np.sqrt(bkg)

cand, bkg_sc, cand_prompt, eff = [], [], [], []

sig_time_windows = [110027, 109645, 89350, 102046]
bkg_time_windows = 157893

#sig_prompt = [14029, 25597, 31300, 31001, 29020]
sig_prompt = [272981, 337944, 327642, 290854]
sig_prompt_err = []
for sig_prompt_i in sig_prompt:
    sig_prompt_err.append(np.sqrt(sig_prompt_i))

eff_max = 0.54
eff_mc = 0.895

#bkg_prompt = 11062
bkg_prompt = 33280
bkg_promot_i = np.sqrt(bkg_prompt)

for i in range(0, len(sig_prompt)):
    bkg_sc.append(bkg*sig_time_windows[i]/bkg_time_windows)
for i in range(0, len(sig_prompt)):
    cand.append(sig[i]-bkg_sc[i])
for i in range(0, len(sig_prompt)):
    cand_prompt.append(sig_prompt[i]-bkg_prompt*sig_time_windows[i]/bkg_time_windows)
    eff.append(cand[i]/cand_prompt[i])

print(eff)

print(len(positions), len(sig_prompt), len(cand))
# Create figure with two vertical subplots (share x)
fig, (ax_top, ax_bottom) = plt.subplots(2, 1, sharex=True,
                                        gridspec_kw={'height_ratios': [1, 1]},
                                        figsize=(10, 8))

ax_top.errorbar(positions, sig_prompt, yerr=sig_prompt_err, fmt='g-', label="gamma")
ax_top.errorbar(positions, cand, yerr=sig_err, fmt='b--', label="gamma+neutron")

ax_top.set_ylabel("Selected Events")
ax_top.legend()
ax_top.grid(alpha=0.3)

ax_bottom.axhline(eff_mc, color='r', linestyle='-', linewidth=1.5, label='MC')
ax_bottom.axhline(eff_max, color='k', linestyle='--', linewidth=1.5, label='Expected')
ax_bottom.errorbar(positions, eff, yerr=0, fmt='-', color='k', label="Estimated Values")
ax_bottom.set_ylim(0.2, 1.0)
ax_bottom.set_xlabel("Position")
ax_bottom.set_ylabel("Neutron Efficiency [%]")
ax_bottom.legend()
ax_bottom.grid(alpha=0.3)
# Out:
# [0.3032822473160558, 0.31153846659919776, 0.3348740176499088, 0.34939392935110636]
# 4 4 4

# %%
# Runs array and input path
run = ['2385', '2386', '2387', '2388', '2389']
# Ensure `input_path` is defined in your environment
# Example placeholder:
# input_path = "/path/to/data/"

# --- Load first run to establish common bin centers ---
first_run_file = os.path.join(input_path, f'histograms_run{run[0]}_40ns.npz')
d = np.load(first_run_file)
bin_centers_common = d['bins_deltat'].astype(float)
counts_sum = np.zeros_like(d['deltat'], dtype=float)

# Add first run
counts_sum += d['deltat'].astype(float)

# Load remaining runs, add to sum (interpolating if needed)
for r in run[1:]:
    fn = os.path.join(input_path, f'histograms_run{r}_40ns.npz')
    data = np.load(fn)
    bc = data['bins_deltat'].astype(float)
    counts = data['deltat'].astype(float)

    # Interpolate counts to match common bin centers
    if bc.shape != bin_centers_common.shape or not np.allclose(bc, bin_centers_common):
        interp_counts = np.interp(bin_centers_common, bc, counts, left=0.0, right=0.0)
        counts_sum += interp_counts
    else:
        counts_sum += counts

# Reconstruct bin edges from centers (assumes roughly uniform spacing)
if len(bin_centers_common) > 1:
    widths = np.diff(bin_centers_common)
    median_width = np.median(widths)
else:
    median_width = 1.0
bin_edges = np.concatenate([bin_centers_common - median_width / 2.0,
                            [bin_centers_common[-1] + median_width / 2.0]])

# ---- Adjust data_mc arrays ----
# Ensure `data_mc` is loaded or replace with real data
# Example placeholder for `data_mc`:
# data_mc = np.load(input_path + "data_mc.npz")
bin_edges_loaded_mc = data_mc['bins_deltat']
values_loaded_mc = data_mc['deltat']

bin_centers_mc = 0.5 * (bin_edges_loaded_mc[:-1] + bin_edges_loaded_mc[1:])

# Interpolate values_loaded_mc to align with bin_centers_common
if bin_centers_mc.shape != bin_centers_common.shape or not np.allclose(bin_centers_mc, bin_centers_common):
    interp_values_loaded_mc = np.interp(bin_centers_common, bin_centers_mc, values_loaded_mc, left=0.0, right=0.0)
else:
    interp_values_loaded_mc = values_loaded_mc

hist_time_n_capture = interp_values_loaded_mc

# Plot settings and range
plot_min, plot_max = 0, 150
mask_in_range = (bin_centers_common >= 8) & (bin_centers_common <= 150)

# Compute scale factor to match maxima in the (5,150) µs window
max_runs_in_range = np.max(counts_sum[mask_in_range]) if np.any(mask_in_range) else np.max(counts_sum)
max_wcsim_in_range = np.max(hist_time_n_capture[mask_in_range]) if np.any(mask_in_range) else np.max(hist_time_n_capture)
scale_factor = (max_runs_in_range / max_wcsim_in_range) if max_wcsim_in_range > 0 else 1.0
scaled_hist_time_n_capture = hist_time_n_capture * scale_factor

# Compute Poisson errors for summed counts (sqrt(N))
yerr = np.sqrt(counts_sum)
# Ensure a minimum error for visibility
yerr = np.maximum(yerr, 1.0)

# Prepare ratio (Data - MC) / Data and propagate errors
mc = scaled_hist_time_n_capture.astype(float)
data = counts_sum.astype(float)
data_err = yerr

ratio = np.full_like(data, np.nan, dtype=float)
ratio_err = np.full_like(data, np.nan, dtype=float)

mask_mc_pos = mc > 0
ratio[mask_mc_pos] = (data[mask_mc_pos] - mc[mask_mc_pos]) / data[mask_mc_pos]
ratio_err[mask_mc_pos] = data_err[mask_mc_pos] / mc[mask_mc_pos]

# Fit Data and MC to exponential function
def exp_func(x, A, tau):
    return A * np.exp(-x / tau)

popt, pcov = curve_fit(exp_func, bin_centers_common[1:-6], data[1:-6], p0=(max(data), 500))
x_fit = np.arange(int(bin_centers_common[1]), int(bin_centers_common[-6]), 1)
A_fit, tau_fit = popt
A_err, tau_err = np.sqrt(np.diag(pcov))

print(f"Fit Data: A = {A_fit:.2f}, tau = {tau_fit:.2f}")

popt_mc, pcov_mc = curve_fit(exp_func, bin_centers_common[1:-6], mc[1:-6], p0=(max(mc), 500))
A_fit_mc, tau_fit_mc = popt_mc
A_err_mc, tau_err_mc = np.sqrt(np.diag(pcov_mc))

print(f"Fit MC: A = {A_fit_mc:.2f}, tau = {tau_fit_mc:.2f}")

# Create figure with two vertical subplots
fig, (ax_top, ax_bottom) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios': [3, 1]}, figsize=(10, 8))

# Top plot: Data and MC comparison
ax_top.errorbar(bin_centers_common, counts_sum, yerr=yerr, fmt='o', color='C0',
             ecolor='C0', elinewidth=1.5, capsize=3, markersize=6,
             label='Runs summed')

ax_top.step(bin_centers_common, scaled_hist_time_n_capture, where='post', linewidth=2, color='red', label=f'WCSim (scaled)')
ax_top.plot(x_fit, exp_func(x_fit, *popt), 'r-', label=f'Fit Data: A·exp(-x/τ), τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs', color="black")

ax_top.set_xlim(plot_min, plot_max)
ax_top.set_ylim(0, 200)
ax_top.set_ylabel('Number of signal candidates')
ax_top.grid(alpha=0.3)
ax_top.legend()

# Bottom plot: Ratio and propagation of errors
ax_bottom.errorbar(bin_centers_common[mask_mc_pos], ratio[mask_mc_pos],
                   yerr=ratio_err[mask_mc_pos], fmt='o', color='C0',
                   ecolor='C0', elinewidth=1.0, capsize=3, markersize=4)
ax_bottom.axhline(0.3, color='k', linestyle='--', linewidth=1)
ax_bottom.axhline(-0.3, color='k', linestyle='--', linewidth=1)
ax_bottom.set_xlabel(r'$\Delta t$ ($\mu$s)')
ax_bottom.set_ylabel('(Data - MC) / Data')
ax_bottom.grid(alpha=0.3)

finite = np.isfinite(ratio)
if np.any(finite):
    rmed = np.nanmedian(ratio[finite])
    rstd = np.nanstd(ratio[finite])
    ymin, ymax = max(0.0, rmed - 3 * rstd), rmed + 3 * rstd
    if ymin == ymax:
        ymin, ymax = 0.5, 1.5
    ax_bottom.set_ylim(-2, 2)
else:
    ax_bottom.set_ylim(0.5, 1.5)

plt.tight_layout()
plt.savefig(os.path.join(input_path, 'capture_time.png'), dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb Cell 94 line 8
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y162sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> run = ['2385', '2386', '2387', '2388', '2389']
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y162sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # Ensure `input_path` is defined in your environment
# ...

# %%
df = df[(df.delayed_x < (pos[0]+60)) & (df.delayed_x > (pos[0]-60)) & (df.delayed_y < (pos[1]+60)) & (df.delayed_y > (pos[1]-60)) & (df.delayed_z < (pos[2]+60)) & (df.delayed_z > (pos[2]-60))]
df_bkg = df_bkg[(df_bkg.delayed_x < (pos[0]+60)) & (df_bkg.delayed_x > (pos[0]-60)) & (df_bkg.delayed_y < (pos[1]+60)) & (df_bkg.delayed_y > (pos[1]-60)) & (df_bkg.delayed_z < (pos[2]+60)) & (df_bkg.delayed_z > (pos[2]-60))]

# %%
import numpy as np
import matplotlib.pyplot as plt

cols = ["delayed_x", "delayed_y", "delayed_z"]
labels = ["X [cm]", "Y [cm]", "Z [cm]"]

source_pos = {"delayed_x": pos[0], "delayed_y": pos[1], "delayed_z": pos[2]}
alpha = N_events_bkg / N_events_sig  # scale signal to background exposure

fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharey=True, constrained_layout=True)

for ax, col, label in zip(axes, cols, labels):
    s = df[col].to_numpy()
    b = df_bkg[col].to_numpy()
    s = s[np.isfinite(s)]
    b = b[np.isfinite(b)]

    # Common bins from combined range
    xmin = np.min([s.min(), b.min()]) if len(s) and len(b) else (s.min() if len(s) else b.min())
    xmax = np.max([s.max(), b.max()]) if len(s) and len(b) else (s.max() if len(s) else b.max())
    bins = np.linspace(xmin, xmax, 20)

    # Bin counts and subtraction: (scaled signal) - background
    s_counts, _ = np.histogram(s, bins=bins)
    b_counts, _ = np.histogram(b, bins=bins)
    diff = alpha * s_counts - b_counts

    # (optional) Poisson uncertainty band: Var = alpha^2*S + B
    diff_sigma = np.sqrt((alpha**2) * s_counts + b_counts)

    # Plot only the subtraction
    ax.step(bins[:-1], diff, where="post", color="k", linewidth=2, label="candidates")
    ax.fill_between(
        bins[:-1], diff - diff_sigma, diff + diff_sigma,
        step="post", color="k", alpha=0.15, linewidth=0
    )
    ax.axhline(0, color="k", linewidth=1, alpha=0.4)

    # Source marker line
    ax.axvline(source_pos[col], color="k", linestyle="--", linewidth=1.5, label="Source position")

    ax.set_xlabel(label)
    ax.grid(alpha=0.3)
    if col == "delayed_x":
        ax.legend()

axes[0].set_ylabel("Events (scaled subtraction)")
fig.suptitle(f"AmBe Run {sig_run} - Delayed Candidates (Subtracted)")
plt.show()

# %%
prompt_nhits = df.DeltaT.values
prompt_nhits_bkg = df_bkg.DeltaT.values

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(0, 150))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist, where='post', label=f'background - run {bkg_run}', color='red', lw=2)
plt.step(bins_edges[:-1], hist_sig * N_events_bkg / N_events_sig, where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.xlabel(r'$\Delta t$ ($\mu$s)')
plt.ylabel('events (a.u.)')
plt.title(f'Delayed signal candidates - Run {sig_run}')
plt.legend()
plt.grid(alpha=0.3)

plt.figure()
plt.step(bins_edges[:-1], hist_sig*N_events_bkg/N_events_sig - hist, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel(r'$\Delta t$ ($\mu$s)')
plt.ylabel('Number of signal candidates')
plt.grid(alpha=0.3)
plt.legend()
plt.show()

bin_centers = 0.5 * (bins_edges[:-1] + bins_edges[1:])
values = hist_sig * N_events_bkg / N_events_sig - hist

np.savez(f'/data/halmazan/WCTE/data/AmBeCandidates/histograms_run{sig_run}_40ns.npz', deltat=values, bins_deltat=bin_centers)


scale = N_events_bkg / N_events_sig
sig_scaled = hist_sig * scale
data = sig_scaled - hist

# Proper approx errors for (scale*sig - bkg)
errors = np.sqrt((scale**2) * hist_sig + hist)

xmin = 20.0  # microseconds

mask = (
    np.isfinite(errors) &
    (errors > 0) &
    (bin_centers > xmin)
    # optional:
    # & (data > 0)
)

# Fit only bins with finite errors and positive content (optional but helps)
#mask = np.isfinite(errors) & (errors > 0) & (data > 0)

x = bin_centers[mask]
y = data[mask]
s = errors[mask]

def exp_func(x, A, tau):
    return A*np.exp(-x/tau)

p0 = (y.max(), 30.0, 0.0)
bounds = ([0, 1e-3, -np.inf], [np.inf, np.inf, np.inf])

popt, pcov = curve_fit(exp_func, x, y, p0=(x.max(), 30.0))
A_fit, tau_fit = popt
A_err, tau_err = np.sqrt(np.diag(pcov))  # Error en A y tau

print(f"Ajuste: A = {A_fit:.2f}, tau = {tau_fit:.2f}")

plt.figure()
plt.step(bins_edges[:-1], data, where='post', linewidth=2, label='Data', color='green')
plt.errorbar(bin_centers, data, yerr=errors, fmt='none', ecolor='black', elinewidth=1, capsize=2)
x_fit = np.linspace(xmin, bin_centers[mask].max(), 400)
plt.plot(x_fit, exp_func(x_fit, *popt), '-', color="black", label=f'Fit data: A·exp(-x/τ), τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs')
#x_fit = np.arange(int(bin_centers[1]), int(bin_centers[-6]), 1)
#plt.plot(x_fit, exp_func(x_fit, *popt), 'r-', label=f'Fit data: A·exp(-x/τ), τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs', color="black")
plt.xlabel(r'Time ($\mu$s)')
plt.ylabel('Number of signal candidates')
plt.grid(alpha=0.3)
plt.title(f'Delayed signal candidates - Run {sig_run}')
plt.legend()
plt.tight_layout()
plt.ylim(bottom = 0)
plt.show()
# Out:
# Ajuste: A = 94.94, tau = 81.84

# %%
# --- Input values ---
N_prompts_sig = int(df_summary_sig["prompt_candidates"].iloc[0])
N_prompts_bkg = int(df_summary_bkg["prompt_candidates"].iloc[0])

N_events_sig = np.max(df["event_number"])
N_events_bkg = np.max(df_bkg["event_number"])

N_prompts_cand = N_prompts_sig - N_prompts_bkg*N_events_sig/N_events_bkg

N_events_sel_sig = len(df["event_number"])
N_events_sel_bkg = len(df_bkg["event_number"])

N_events_cand = N_events_sel_sig-N_events_sel_bkg*N_events_sig/N_events_bkg



# --- Statistical uncertainties ---
# Poisson error for counts
err_N_sig = np.sqrt(N_events_sel_sig)
err_N_bkg = np.sqrt(N_events_sel_bkg)
err_N_cand = np.sqrt(N_events_cand)


# --- Create summary table ---
results = {
    f"Run {sig_run}": [
        "Time Windows",
        "Prompt Candidates",
        "Selected Events",
        "Efficiency [%]"
    ],
    "Signal": [
        N_events_sig,
        N_prompts_sig,
        f"{N_events_sel_sig}±{err_N_sig:.1f}",
        N_events_sel_sig*100/N_prompts_sig,
    ],
    "Background": [
        N_events_bkg,
        N_prompts_bkg,
        f"{N_events_sel_bkg}±{err_N_bkg:.1f}",
        N_events_sel_bkg*100/N_prompts_bkg,
    ],
    "Candidates": [
        "-",
        N_prompts_cand,
        f"{N_events_cand:1f}±{err_N_cand:.1f}",
        N_events_cand*100/N_prompts_cand
    ]
}

df_results = pd.DataFrame(results)

# Show nicely
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,3))
ax.axis('off')
tbl = ax.table(
    cellText=df_results.values,
    colLabels=df_results.columns,
    loc='center',
    cellLoc='center'
)
tbl.auto_set_font_size(False)
tbl.set_fontsize(9)
tbl.scale(1.2, 1.2)

plt.show()

# %%
df_results_numeric = pd.DataFrame({
    "data_type": ["signal", "bkg", "cand"],
    "time_windows": [N_events_sig, N_events_bkg, np.nan],
    "prompt_candidates": [N_prompts_sig, N_prompts_bkg, N_prompts_cand],
    "selected_events": [N_events_sel_sig, N_events_sel_bkg, N_events_cand],
    "efficiency": [
        N_events_sel_sig * 100 / N_prompts_sig,
        N_events_sel_bkg * 100 / N_prompts_bkg,
        N_events_cand * 100 / N_prompts_cand,
    ],
    "capture_time": [np.nan, np.nan, tau_fit], 
    "capture_time_err": [np.nan, np.nan, tau_err]
})

# --- Save to CSV ---
out_csv = f"/scratch/halmazan/WCTE/files/data/AmBeCandidates/selection_numbers_run_{sig_run}_test2.csv"
df_results_numeric.to_csv(out_csv, index=False)

print("Saved:", out_csv)
display(df_results_numeric)  # if you're in a notebook
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb Cell 61 line 1
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y112sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> # --- Save to CSV ---
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y112sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> out_csv = f"/scratch/halmazan/WCTE/files/data/AmBeCandidates/selection_numbers_run_{sig_run}_test2.csv"
# ...

# %%
prompt_nhits = df_gamma.prompt_ti.values
prompt_nhits_bkg = df.prompt_time.values

# --- histograms (same binning) ---
hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=25, range=(0, 270000))
hist_sig, _      = np.histogram(prompt_nhits,     bins=bins_edges)  # prompt

# --- ratio (cand / prompt), in percent ---
ratio = np.divide(
    hist.astype(float),
    hist_sig.astype(float),
    out=np.full_like(hist, np.nan, dtype=float),
    where=(hist_sig != 0)
) * 100.0

# Simple propagated error assuming Poisson counts in both:
# r = (A/B)*100 ;  σ_r/r = sqrt( (σA/A)^2 + (σB/B)^2 ) with σA=sqrt(A), σB=sqrt(B)
A = hist.astype(float)      # candidates
B = hist_sig.astype(float)  # prompt
ratio_err = np.full_like(ratio, np.nan, dtype=float)
mask = (A > 0) & (B > 0)
ratio_err[mask] = ratio[mask] * np.sqrt(1.0 / A[mask] + 1.0 / B[mask])

# x coordinates for "post" steps
x = bins_edges[:-1]

# --- figure with ratio panel ---
fig, (ax, rax) = plt.subplots(
    2, 1, sharex=True,
    gridspec_kw={"height_ratios": [3, 1], "hspace": 0.05},
    figsize=(7, 6)
)

# top
ax.step(x, hist, where="post", label="candidates", color="blue", lw=2, linestyle="--")
ax.step(x, hist_sig, where="post", label="prompt", color="blue", lw=2)
ax.set_ylabel("events (a.u.)")
ax.set_title("Prompt Time in TW")
ax.legend()
ax.grid(alpha=0.3)

# bottom ratio
rax.axhline(60.0,  color="red",   lw=2, alpha=0.9, ls="--")     # 60% reference line
rax.step(x, ratio, where="post", color="blue", lw=2)

# optional: ratio error bars at bin centers
centers = 0.5 * (bins_edges[:-1] + bins_edges[1:])
rax.errorbar(centers, ratio, yerr=ratio_err, fmt="none", ecolor="blue", elinewidth=1, alpha=0.7)

rax.set_xlabel("prompt time (ms)")
rax.set_ylabel("ratio (%)")
rax.set_ylim(0, 65)# np.nanmax(ratio) * 1.2 if np.isfinite(np.nanmax(ratio)) else 200)
rax.grid(alpha=0.3)

plt.show()

# %%
# -------------------------
# "prompt" (green solid)
# -------------------------
prompt_nhits = df_gamma.prompt_trms.values
prompt_nhits_bkg = df_gamma_bkg.prompt_trms.values

hist_p_bkg, bins_edges = np.histogram(
    prompt_nhits_bkg, bins=25, range=(prompt_t_rms_min, prompt_t_rms_max)
)
hist_p_sig, _ = np.histogram(prompt_nhits, bins=bins_edges)

# scaled difference: sig*(Nbkg/Nsig) - bkg
diff_prompt = hist_p_sig * (N_events_bkg / N_events_sig) - hist_p_bkg

# -------------------------
# "candidate" (green dashed)
# -------------------------
prompt_nhits = df.prompt_trms.values
prompt_nhits_bkg = df_bkg.prompt_trms.values

hist_c_bkg, _ = np.histogram(
    prompt_nhits_bkg, bins=25, range=(prompt_t_rms_min, prompt_t_rms_max)
)
hist_c_sig, _ = np.histogram(prompt_nhits, bins=bins_edges)

diff_cand = hist_c_sig * (N_events_bkg / N_events_sig) - hist_c_bkg

# -------------------------
# Ratio panel: cand / prompt (in %), + red 60% line
# -------------------------
ratio = np.divide(
    diff_cand.astype(float),
    diff_prompt.astype(float),
    out=np.full_like(diff_cand, np.nan, dtype=float),
    where=(diff_prompt != 0)
) * 100.0

# Optional errors (approx): treat each diff as independent with variance ~ (k^2 * sig + bkg)
# where k = N_events_bkg/N_events_sig and sig,bkg are Poisson.
k = (N_events_bkg / N_events_sig)
var_prompt = (k**2) * hist_p_sig.astype(float) + hist_p_bkg.astype(float)
var_cand   = (k**2) * hist_c_sig.astype(float) + hist_c_bkg.astype(float)
sigma_prompt = np.sqrt(var_prompt)
sigma_cand   = np.sqrt(var_cand)

ratio_err = np.full_like(ratio, np.nan, dtype=float)
mask = (diff_prompt != 0) & np.isfinite(diff_prompt) & np.isfinite(diff_cand)
ratio_err[mask] = np.abs(ratio[mask]) * np.sqrt(
    (sigma_cand[mask] / np.where(diff_cand[mask] != 0, np.abs(diff_cand[mask]), np.nan))**2 +
    (sigma_prompt[mask] / np.abs(diff_prompt[mask]))**2
)

# x for step plots
x = bins_edges[:-1]
centers = 0.5 * (bins_edges[:-1] + bins_edges[1:])

# -------------------------
# Plot
# -------------------------
fig, (ax, rax) = plt.subplots(
    2, 1, sharex=True,
    gridspec_kw={"height_ratios": [3, 1], "hspace": 0.05},
    figsize=(7, 6)
)

# top: scaled differences
ax.step(x, diff_prompt, where="post", linewidth=2, color="green", label="prompt")
ax.step(x, diff_cand,   where="post", linewidth=2, color="green", linestyle="--", label="candidate")
ax.set_ylabel("events (a.u.)")
ax.set_title("Prompt signal candidates")
ax.legend()
ax.grid(alpha=0.3)

# bottom: ratio cand/prompt (%)
rax.axhline(100.0, color="black", lw=1, alpha=0.7)          # 100%: cand == prompt
rax.axhline(60.0,  color="red",   lw=2, alpha=0.9, ls="--") # 60% reference
rax.step(x, ratio, where="post", color="green", lw=2)

# optional: ratio error bars (can be noisy when diffs ~ 0)
rax.errorbar(centers, ratio, yerr=ratio_err, fmt="none", ecolor="green", elinewidth=1, alpha=0.6)

rax.set_xlabel("tRMS [ns]")
rax.set_ylabel("ratio (%)")
rax.set_ylim(0, np.nanmax(ratio) * 1.2 if np.isfinite(np.nanmax(ratio)) else 200)
rax.grid(alpha=0.3)

plt.show()

# %%
##############

# %%
import numpy as np
import pandas as pd

# --- Input values ---
N_events_sig = np.max(df["event_number"])
N_events_bkg = np.max(df_bkg["event_number"])

N_events_sel_sig = df["event_number"].nunique()
N_events_sel_bkg = df_bkg["event_number"].nunique()*N_events_sig/N_events_bkg

window_time = 270e-6  # seconds per time window

# --- Compute rates ---
rate_sig = N_events_sel_sig / (N_events_sig * window_time)
rate_bkg = N_events_sel_bkg / (N_events_bkg * window_time)
rate_diff = rate_sig - rate_bkg

# --- Statistical uncertainties ---
# Poisson error for counts
err_N_sig = np.sqrt(N_events_sel_sig)
err_N_bkg = np.sqrt(N_events_sel_bkg)

# propagate to rates: rate = N_sel / (N_total * window_time)
err_rate_sig = err_N_sig / (N_events_sig * window_time)
err_rate_bkg = err_N_bkg / (N_events_bkg * window_time)

# difference uncertainty (assuming independence)
err_rate_diff = np.sqrt(err_rate_sig**2 + err_rate_bkg**2)

# --- Create summary table ---
results = {
    f"Run {sig_run}": [
        "Signal Time Windows",
        "Background Time Windows",
        "Selected Signal Events",
        "Selected Background Events",
        "Signal Rate [Hz]",
        "Background Rate [Hz]",
        "Candidate Rate (Sig - Bkg) [Hz]",
    ],
    "Value": [
        N_events_sig,
        N_events_bkg,
        N_events_sel_sig,
        N_events_sel_bkg,
        rate_sig,
        rate_bkg,
        rate_diff,
    ],
    "Uncertainty": [
        "",  # time windows: no Poisson error
        "",
        f"±{err_N_sig:.1f}",
        f"±{err_N_bkg:.1f}",
        f"±{err_rate_sig:.3e}",
        f"±{err_rate_bkg:.3e}",
        f"±{err_rate_diff:.3e}",
    ]
}

df_results = pd.DataFrame(results)

# Show nicely
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,3))
ax.axis('off')
tbl = ax.table(
    cellText=df_results.values,
    colLabels=df_results.columns,
    loc='center',
    cellLoc='center'
)
tbl.auto_set_font_size(False)
tbl.set_fontsize(9)
tbl.scale(1.2, 1.2)

plt.show()

R = 3.7e6 #Bq
eff_gn = 0.6
d = 0.025 

eff = (N_events_sel_sig - N_events_sel_bkg) / (R * eff_gn * window_time * N_events_sig * d)
sigma_eff = (1/(R*eff_gn*window_time*d*N_events_sig)) * np.sqrt(
    N_events_sel_sig + N_events_sel_bkg +
    ( (N_events_sel_sig - N_events_sel_bkg)**2 ) / N_events_sig
)
print(f"Neutron Efficiency {eff*100} +- {sigma_eff*100} %")
# Out:
# Neutron Efficiency 0.2756878071144445 +- 0.005462965035035859 %

# %%
#N_events_sel_acc, N_events_sel_acc/5, N_events_sel_sig, N_events_sel_bkg, 
N_events_sel_bkg/N_events_bkg, N_events_sel_acc/(5*N_events_sig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb Cell 64 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y120sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> #N_events_sel_acc, N_events_sel_acc/5, N_events_sel_sig, N_events_sel_bkg,
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y120sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> N_events_sel_bkg/N_events_bkg, N_events_sel_acc/(5*N_events_sig)
#
# NameError: name 'N_events_sel_acc' is not defined

# %%
import numpy as np
import pandas as pd

# --- Input values ---
N_events_sig = np.max(df["event_number"])

N_events_sel_sig = df["event_number"].nunique()

N_events_acc = N_events_sel_sig*5 #np.max(df_acc["event_number"])

N_events_sel_acc = df_acc["event_number"].nunique()/10


window_time = 270e-6  # seconds per time window

# --- Compute rates ---
rate_sig = N_events_sel_sig / (N_events_sig * window_time)
rate_acc = N_events_sel_acc / (N_events_sig * window_time)
rate_diff = rate_sig - rate_acc

# --- Statistical uncertainties ---
# Poisson error for counts
err_N_sig = np.sqrt(N_events_sel_sig)
err_N_acc = np.sqrt(N_events_sel_acc)

# propagate to rates: rate = N_sel / (N_total * window_time)
err_rate_sig = err_N_sig / (N_events_sig * window_time)
err_rate_acc = err_N_acc / (N_events_sig * window_time)

# difference uncertainty (assuming independence)
err_rate_diff = np.sqrt(err_rate_sig**2 + err_rate_acc**2)

# --- Create summary table ---
results = {
    f"Run {sig_run}": [
        "Signal Time Windows",
        "Accidental Time Windows",
        "Selected Signal Events",
        "Selected Accidental Events",
        "Signal Rate [Hz]",
        "Background Rate [Hz]",
        "Candidate Rate (Sig - Bkg) [Hz]",
    ],
    "Value": [
        N_events_sig,
        N_events_acc,
        N_events_sel_sig,
        N_events_sel_acc,
        rate_sig,
        rate_acc,
        rate_diff,
    ],
    "Uncertainty": [
        "",  # time windows: no Poisson error
        "",
        f"±{err_N_sig:.1f}",
        f"±{err_N_acc:.1f}",
        f"±{err_rate_sig:.3e}",
        f"±{err_rate_acc:.3e}",
        f"±{err_rate_diff:.3e}",
    ]
}

df_results = pd.DataFrame(results)

# Show nicely
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,3))
ax.axis('off')
tbl = ax.table(
    cellText=df_results.values,
    colLabels=df_results.columns,
    loc='center',
    cellLoc='center'
)
tbl.auto_set_font_size(False)
tbl.set_fontsize(9)
tbl.scale(1.2, 1.2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb Cell 65 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> N_events_sel_sig = df["event_number"].nunique()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226879706572696f6e2e73772e6568752e6573222c2275736572223a2268616c6d617a616e227d/scratch/halmazan/WCTE/ACES/jupyter_nb/CandidateEvents.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> N_events_acc = N_events_sel_sig*5 #np.max(df_acc["event_number"])
# ...

# %%
prompt_nhits = df.delayed_nhits.values
prompt_nhits_bkg = df_acc.vp_delayed_nhits.values

scale = 1/5#N_events_sel_acc/50/N_events_sel_sig
#N_events_acc = N_events_sig *5

hist, bins_edges = np.histogram(prompt_nhits_bkg, bins=20, range=(delayed_nhits_min, 28))
hist_sig, _ = np.histogram(prompt_nhits, bins = bins_edges)

plt.figure()
plt.step(bins_edges[:-1], hist*scale, where='post', label=f'background - accidentals', color='orange', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig , where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
#plt.step(bins_edges[:-1], hist_sig - hist*N_events_sel_sig/N_events_acc, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel('nHits')
plt.ylabel('events (a.u.)')
plt.title('Delayed signal candidates')
plt.legend()
plt.grid(alpha=0.3)

# %%
cols = ["delayed_x", "delayed_y", "delayed_z"]
cols_acc = ["vp_delayed_x", "vp_delayed_y", "vp_delayed_z"]
labels = ["X [cm]", "Y [cm]", "Z [cm]"]

source_pos = {"delayed_x": pos[0], "delayed_y": pos[1], "delayed_z": pos[2]}

alpha = 5#N_events_sig/N_events_acc  # scale signal to background exposure

fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharey=True, constrained_layout=True)

for ax, col, col_acc, label in zip(axes, cols, cols_acc, labels):
    # Drop non-finite
    s = df[col].to_numpy()
    b = df_acc[col_acc].to_numpy()
    s = s[np.isfinite(s)]
    b = b[np.isfinite(b)]

    # Common bins from combined range
    xmin = np.min([s.min(), b.min()]) if len(s) and len(b) else (s.min() if len(s) else b.min())
    xmax = np.max([s.max(), b.max()]) if len(s) and len(b) else (s.max() if len(s) else b.max())
    bins = np.linspace(xmin, xmax, 26)  # 50 bins

    # Histograms: scale signal counts by alpha via weights
    ax.hist(s, bins=bins, weights=np.full(s.shape, alpha), color="blue", alpha=0.6, label=f'signal')
    ax.hist(b, bins=bins, color="orange", alpha=0.6, label=f'background')

    # Source marker line
    vline = source_pos[col]
    ax.axvline(vline, color="k", linestyle="--", linewidth=1.5, label="Source position")

    ax.set_xlabel(label)
    ax.grid(alpha=0.3)
    if(col =='delayed_x'):
        ax.legend()

axes[0].set_ylabel("Events (a.u.)")
fig.suptitle(f"AmBe Run {sig_run} - Delayed Candidates")
plt.show()

# %%
deltaT_val = df.DeltaT.values
deltaT_val_bkg = df_acc.DeltaT.values

hist, bins_edges = np.histogram(deltaT_val_bkg, bins=30, range=(0, 150))
hist_sig, _ = np.histogram(deltaT_val, bins = bins_edges)
scale = 1/5#N_events_sel_sig/N_events_acc

plt.figure()
plt.step(bins_edges[:-1], hist*N_events_sel_sig/N_events_acc, where='post', label=f'background - accidentals', color='orange', lw=2, linestyle = '--')
plt.step(bins_edges[:-1], hist_sig , where='post', label=f'signal - run {sig_run}', color='blue', lw=2)
plt.xlabel(r'$\Delta t$ ($\mu$s)')
plt.ylabel('events (a.u.)')
plt.title(f'Delayed signal candidates - Run {sig_run}')
plt.legend()
plt.grid(alpha=0.3)

plt.figure()
plt.step(bins_edges[:-1], hist_sig - hist*N_events_sel_sig/N_events_acc, where='post', linewidth=2, color='green', label=f'signal - bkg')
plt.xlabel(r'$\Delta t$ ($\mu$s)')
plt.ylabel('Number of signal candidates')
plt.grid(alpha=0.3)
plt.legend()
plt.show()


np.savez(f'/scratch/halmazan/WCTE/files/data/AmBeCandidates/histograms_run{sig_run}_acc_noWin.npz', deltat=values, bins_deltat=bin_centers)


bin_centers = 0.5 * (bins_edges[:-1] + bins_edges[1:])
values = hist_sig  - hist*scale

bin_centers = (bins_edges[:-1] + bins_edges[1:]) / 2  
data = hist_sig  - hist*scale
errors = np.sqrt(data)


popt, pcov = curve_fit(exp_func, bin_centers[1:-1], data[1:-1], p0=(max(data), 500))


# popt contiene los parámetros A y tau
A_fit, tau_fit = popt
A_err, tau_err = np.sqrt(np.diag(pcov))  # Error en A y tau

print(f"Ajuste: A = {A_fit:.2f}, tau = {tau_fit:.2f}")

plt.figure()
plt.step(bins_edges[:-1], data, where='post', linewidth=2, label='Data', color='green')
plt.errorbar(bin_centers, data, yerr=errors, fmt='none', ecolor='black', elinewidth=1, capsize=2)
x_fit = np.arange(int(bin_centers[1]), int(bin_centers[-1]), 1)
plt.plot(x_fit, exp_func(x_fit, *popt), 'r-', label=f'Fit data: A·exp(-x/τ), τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs', color="black")
plt.xlabel(r'Time ($\mu$s)')
plt.ylabel('Number of signal candidates')
plt.grid(alpha=0.3)
plt.title(f'Delayed signal candidates - Run {sig_run}')
plt.legend()
plt.tight_layout()
plt.ylim(bottom = 0)
plt.show()
# Out:
# Ajuste: A = 283.66, tau = -3384101062.65
# /tmp/ipykernel_30370/3220376509.py:50: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x_fit, exp_func(x_fit, *popt), 'r-', label=f'Fit data: A·exp(-x/τ), τ ≈ {tau_fit:.0f} ± {tau_err:.0f} μs', color="black")

# %%
R = 3.7e6 #Bq
eff_gn = 0.6
d = 0.025 

eff = (N_events_sel_sig - N_events_sel_acc) / (R * eff_gn * window_time * N_events_sig * d)
sigma_eff = (1/(R*eff_gn*window_time*d*N_events_sig)) * np.sqrt(
    N_events_sel_sig + N_events_sel_acc +
    ( (N_events_sel_sig - N_events_sel_acc)**2 ) / N_events_sig
)
print(f"Neutron Efficiency {eff*100} +- {sigma_eff*100} %")
# Out:
# Neutron Efficiency 0.03636958775072284 +- 0.0016459673673390927 %

# %%
len(df_acc.vp_delayed_nhits.values), len(df_acc.DeltaT.values)
# Out:
# (5173, 5173)

# %%
plt.hist2d(df.DeltaT.values, df.delayed_nhits.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
plt.ylim(10, 27)  # Set x-axis limits
plt.xlim(0, 150)
plt.xlabel('tcapt [ns]')
plt.ylabel('nHits')
plt.title(f'Signal')
plt.show()

# %%
plt.hist2d(df_acc.DeltaT.values, df_acc.vp_delayed_nhits.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
plt.ylim(10, 27)  # Set x-axis limits
plt.xlim(0, 150)
plt.xlabel('tcapt [ns]')
plt.ylabel('nHits')
plt.title(f'Accidentals')
plt.show()

# %%
plt.hist2d(df_bkg.DeltaT.values, df_bkg.delayed_nhits.values, bins=20, cmin=0.0001)
plt.colorbar(label='Density')
plt.ylim(10, 27)  # Set x-axis limits
plt.xlim(0, 150)
plt.xlabel('tcapt [ns]')
plt.ylabel('nHits')
plt.title(f'Background')
plt.show()
